# %%
from packages.maths import addition
print(addition(2, 3))
# Out:
# 5

# %%
from packages import maths
maths.addition(2, 3)
# Out:
# 5

# %%
from packages.subpackage import mult
mult.multiply(2, 3)
# Out:
# 6
