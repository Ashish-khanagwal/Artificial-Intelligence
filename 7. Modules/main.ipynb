# %%
from packages.maths import addition
print(addition(2, 3))
# Out:
# 5

# %%
from packages import maths
maths.addition(2, 3)
# Out:
# 5

# %%
from packages.subpackage import mult
mult.multiply(2, 3)
# Out:
# 6

# %%
import os
print(os.getcwd())
# Out:
# /Users/ashishkhanagwal/Documents/ASHISH/2. TECH/Artificial-Intelligence/7. Modules

# %%
os.mkdir('test')

# %%
# High level operations on files and collection of files

import shutil
shutil.copyfile('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Sterlization

import json
data={'name': 'Ashish', 'age': 24}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Ashish", "age": 24}
# <class 'str'>
# {'name': 'Ashish', 'age': 24}
# <class 'dict'>

# %%
## csv

import csv

with open('example.csv', mode='w', newline='') as file:
  writer=csv.writer(file)
  writer.writerow(['name', 'age'])
  writer.writerow(['Ashish', 24])

with open('example.csv', mode='r') as file:
  reader=csv.reader(file)
  for row in reader:
    print(row)
# Out:
# ['name', 'age']
# ['Ashish', '24']

# %%
## Datetime

from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2025-12-04 16:47:01.892051
# 2025-12-03 16:47:01.892051

# %%
## time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1764847083.331836
# 1764847085.33744

# %%
## Regular Expression

import re
pattern = r'\d+'
text = 'There are 123 456 apples'
match = re.search(pattern, text)
print(match.group())
# Out:
# 123

# %%
# make new directory
import os
new_directory = 'package'
os.mkdir(new_directory)
print(f"New directory: {new_directory} created")
# Out:
# New directory: package created

# %%
# Listing files and Directories
items = os.listdir('.')
print(items)
# Out:
# ['destination.txt', 'main.ipynb', 'example.csv', 'test', 'source.txt', 'packages', 'package']

# %%
# Joining file paths
dir_name = 'folder'
file_name = 'file.txt'
full_path = os.path.join(dir_name, file_name)
print(full_path)
# Out:
# folder/file.txt

# %%
# Joining file paths
dir_name = 'folder'
file_name = 'file.txt'
full_path = os.path.join(os.getcwd(),dir_name, file_name)
print(full_path)
# Out:
# /Users/ashishkhanagwal/Documents/ASHISH/2. TECH/Artificial-Intelligence/7. Modules/folder/file.txt

# %%
path = 'example.txt'
if os.path.exists(path):
  print(f"Yes, The path {path} exits!")
else:
  print(f"No, Tha path {path} doesn't exists! Let me create the file.")
  with open('example.txt', 'w') as file:
    file.write("Hey, Here i am, i noticed you were looking for me.")
# Out:
# No, Tha path example.txt doesn't exists! Let me create the file.

# %%
# Checking if a itme is a file or a directory.

if os.path.isfile(path):
  print(F"The path {path} is a file")
elif os.path.isdir(path):
  print(f"The path {path} is a directory")
else:
  print(f"The path {path} is neither a file nor a directory.")
# Out:
# The path example.txt is a file

# %%
# Getting the absolute path
relative_path = 'example.txt'
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# /Users/ashishkhanagwal/Documents/ASHISH/2. TECH/Artificial-Intelligence/7. Modules/example.txt
