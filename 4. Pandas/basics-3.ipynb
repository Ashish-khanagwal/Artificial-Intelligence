# %% [markdown]
# ## Converting the datatype of a particular column.

# %%
import pandas as pd
import numpy as np

# %%
# Creating DataFrames using a dictionary
people = {
    "first": [
        "Ashish", "Corey", "John", "Meera", "Arjun",
        "Sophia", "Liam", "Hannah", "Carlos", "Jisoo"
    ],
    "last": [
        "Khanagwal", "Anderson", "Doe", "Patel", "Singh",
        "Williams", "Brown", "Nguyen", "Garcia", "Kim"
    ],
    "email_address": [
        "ashishkhanagwal@gmail.com",
        "coreyschafar@gmail.com",
        "timdavid@gmail.com",
        "meerapatel@gmail.com",
        "arjunsingh@gmail.com",
        "sophiawilliams@gmail.com",
        "liambrown@gmail.com",
        "hannahnguyen@gmail.com",
        "carlosgarcia@gmail.com",
        "jisookim@gmail.com",
    ],
    "age": [24, 27, 26, 25, 29, 31, 28, 24, 32, 26],
    "Profession": [
        "AI Engineer", "Tutor", "Software Developer", "Data Scientist", "Product Manager",
        "UX Designer", "DevOps Engineer", "Research Analyst", "Systems Architect", "ML Engineer"
    ],
    "Company": [
        "Meta", "YouTube", "Google", "Microsoft", "Amazon",
        "Apple", "Netflix", "Tesla", "IBM", "OpenAI"
    ],
    "Score": [85, 90, 88, 92, 89, 87, 91, 86, 93, 95]
}

# %%
df = pd.DataFrame(people)
df
# Out:
#     first       last              email_address  age          Profession  \
# 0  Ashish  Khanagwal  ashishkhanagwal@gmail.com   24         AI Engineer
# 1   Corey   Anderson     coreyschafar@gmail.com   27               Tutor
# 2    John        Doe         timdavid@gmail.com   26  Software Developer
# 3   Meera      Patel       meerapatel@gmail.com   25      Data Scientist
# 4   Arjun      Singh       arjunsingh@gmail.com   29     Product Manager
# 5  Sophia   Williams   sophiawilliams@gmail.com   31         UX Designer
# 6    Liam      Brown        liambrown@gmail.com   28     DevOps Engineer
# 7  Hannah     Nguyen     hannahnguyen@gmail.com   24    Research Analyst
# 8  Carlos     Garcia     carlosgarcia@gmail.com   32   Systems Architect
# 9   Jisoo        Kim         jisookim@gmail.com   26         ML Engineer
#
#      Company  Score
# 0       Meta     85
# 1    YouTube     90
# 2     Google     88
# 3  Microsoft     92
# 4     Amazon     89
# 5      Apple     87
# 6    Netflix     91
# 7      Tesla     86
# 8        IBM     93
# 9     OpenAI     95

# %% [markdown]
# ### 1. Using .astype()
# - This is the most common and easiest way.

# %%
df['age'] = df['age'].astype(str)
# This will covert data type of age from int to string.
df['age']

df['Score'] = df['Score'].astype(float)
# This will convert the data type of score from int to float.
df['Score']
# Out:
# 0    85.0
# 1    90.0
# 2    88.0
# 3    92.0
# 4    89.0
# 5    87.0
# 6    91.0
# 7    86.0
# 8    93.0
# 9    95.0
# Name: Score, dtype: float64

# %% [markdown]
# ### 2. Using `pd.to_numeric()`, `pd.to_datetime()`, `pd.to_timedelta()`
# - These are special functions for certain datatypes.

# %%
# To numbers (int/float):
df['age'] = pd.to_numeric(df['age'])
df['age']
# Converted from string to integer.
# Out:
# 0    24
# 1    27
# 2    26
# 3    25
# 4    29
# 5    31
# 6    28
# 7    24
# 8    32
# 9    26
# Name: age, dtype: int64

# %%
# To check data types of the dataframe.
df.dtypes
# Out:
# first             object
# last              object
# email_address     object
# age                int64
# Profession        object
# Company           object
# Score            float64
# dtype: object

# %% [markdown]
# ## Adding and Removing rows and columns
# Adding and removing rows and columns in a pandas DataFrame is a common operation when preparing or cleaning up your data. Here’s how to do it in a clear, friendly way with practical examples:

# %% [markdown]
# ## Adding Columns
# Assign a new column by name:

# %%
df['full name'] = df['first'] + ' ' + df['last']

# %%
df
# Out:
#     first       last              email_address  age          Profession  \
# 0  Ashish  Khanagwal  ashishkhanagwal@gmail.com   24         AI Engineer
# 1   Corey   Anderson     coreyschafar@gmail.com   27               Tutor
# 2    John        Doe         timdavid@gmail.com   26  Software Developer
# 3   Meera      Patel       meerapatel@gmail.com   25      Data Scientist
# 4   Arjun      Singh       arjunsingh@gmail.com   29     Product Manager
# 5  Sophia   Williams   sophiawilliams@gmail.com   31         UX Designer
# 6    Liam      Brown        liambrown@gmail.com   28     DevOps Engineer
# 7  Hannah     Nguyen     hannahnguyen@gmail.com   24    Research Analyst
# 8  Carlos     Garcia     carlosgarcia@gmail.com   32   Systems Architect
# 9   Jisoo        Kim         jisookim@gmail.com   26         ML Engineer
#
#      Company  Score         full name
# 0       Meta   85.0  Ashish Khanagwal
# 1    YouTube   90.0    Corey Anderson
# 2     Google   88.0          John Doe
# 3  Microsoft   92.0       Meera Patel
# 4     Amazon   89.0       Arjun Singh
# 5      Apple   87.0   Sophia Williams
# 6    Netflix   91.0        Liam Brown
# 7      Tesla   86.0     Hannah Nguyen
# 8        IBM   93.0     Carlos Garcia
# 9     OpenAI   95.0         Jisoo Kim

# %% [markdown]
# ## Removing Columns
# Using drop:

# %%
df.drop(columns=['first', 'last'], inplace = True)
df
# This will remove the 'first' and 'last' columns from the dataframe.
# Removes the column “column_name” from the DataFrame. Use axis=1 for columns.
# Out:
#                email_address  age          Profession    Company  Score  \
# 0  ashishkhanagwal@gmail.com   24         AI Engineer       Meta   85.0
# 1     coreyschafar@gmail.com   27               Tutor    YouTube   90.0
# 2         timdavid@gmail.com   26  Software Developer     Google   88.0
# 3       meerapatel@gmail.com   25      Data Scientist  Microsoft   92.0
# 4       arjunsingh@gmail.com   29     Product Manager     Amazon   89.0
# 5   sophiawilliams@gmail.com   31         UX Designer      Apple   87.0
# 6        liambrown@gmail.com   28     DevOps Engineer    Netflix   91.0
# 7     hannahnguyen@gmail.com   24    Research Analyst      Tesla   86.0
# 8     carlosgarcia@gmail.com   32   Systems Architect        IBM   93.0
# 9         jisookim@gmail.com   26         ML Engineer     OpenAI   95.0
#
#           full name
# 0  Ashish Khanagwal
# 1    Corey Anderson
# 2          John Doe
# 3       Meera Patel
# 4       Arjun Singh
# 5   Sophia Williams
# 6        Liam Brown
# 7     Hannah Nguyen
# 8     Carlos Garcia
# 9         Jisoo Kim

# %%
df['full name'].str.split(' ', expand = True)
# this is how full name column will be split into two seperate columns
# Out:
#         0          1
# 0  Ashish  Khanagwal
# 1   Corey   Anderson
# 2    John        Doe
# 3   Meera      Patel
# 4   Arjun      Singh
# 5  Sophia   Williams
# 6    Liam      Brown
# 7  Hannah     Nguyen
# 8  Carlos     Garcia
# 9   Jisoo        Kim

# %%
# Adding new columns and assigning value at the same time.
df[['first', 'last']] = df['full name'].str.split(' ', expand=True)
df
# Out:
#                email_address  age          Profession    Company  Score  \
# 0  ashishkhanagwal@gmail.com   24         AI Engineer       Meta   85.0
# 1     coreyschafar@gmail.com   27               Tutor    YouTube   90.0
# 2         timdavid@gmail.com   26  Software Developer     Google   88.0
# 3       meerapatel@gmail.com   25      Data Scientist  Microsoft   92.0
# 4       arjunsingh@gmail.com   29     Product Manager     Amazon   89.0
# 5   sophiawilliams@gmail.com   31         UX Designer      Apple   87.0
# 6        liambrown@gmail.com   28     DevOps Engineer    Netflix   91.0
# 7     hannahnguyen@gmail.com   24    Research Analyst      Tesla   86.0
# 8     carlosgarcia@gmail.com   32   Systems Architect        IBM   93.0
# 9         jisookim@gmail.com   26         ML Engineer     OpenAI   95.0
#
#           full name   first       last
# 0  Ashish Khanagwal  Ashish  Khanagwal
# 1    Corey Anderson   Corey   Anderson
# 2          John Doe    John        Doe
# 3       Meera Patel   Meera      Patel
# 4       Arjun Singh   Arjun      Singh
# 5   Sophia Williams  Sophia   Williams
# 6        Liam Brown    Liam      Brown
# 7     Hannah Nguyen  Hannah     Nguyen
# 8     Carlos Garcia  Carlos     Garcia
# 9         Jisoo Kim   Jisoo        Kim

# %% [markdown]
# ## Adding Row

# %%
# New row as DataFrame, and other than 'fist' all values will be set to NaN.
new_row = pd.DataFrame({'first': ['Tony']})
df = pd.concat([df, new_row], ignore_index=True)

# %%
df
# Out:
#                 email_address   age          Profession    Company  Score  \
# 0   ashishkhanagwal@gmail.com  24.0         AI Engineer       Meta   85.0
# 1      coreyschafar@gmail.com  27.0               Tutor    YouTube   90.0
# 2          timdavid@gmail.com  26.0  Software Developer     Google   88.0
# 3        meerapatel@gmail.com  25.0      Data Scientist  Microsoft   92.0
# 4        arjunsingh@gmail.com  29.0     Product Manager     Amazon   89.0
# 5    sophiawilliams@gmail.com  31.0         UX Designer      Apple   87.0
# 6         liambrown@gmail.com  28.0     DevOps Engineer    Netflix   91.0
# 7      hannahnguyen@gmail.com  24.0    Research Analyst      Tesla   86.0
# 8      carlosgarcia@gmail.com  32.0   Systems Architect        IBM   93.0
# 9          jisookim@gmail.com  26.0         ML Engineer     OpenAI   95.0
# 10                        NaN   NaN                 NaN        NaN    NaN
#
#            full name   first       last
# 0   Ashish Khanagwal  Ashish  Khanagwal
# 1     Corey Anderson   Corey   Anderson
# 2           John Doe    John        Doe
# 3        Meera Patel   Meera      Patel
# 4        Arjun Singh   Arjun      Singh
# 5    Sophia Williams  Sophia   Williams
# 6         Liam Brown    Liam      Brown
# 7      Hannah Nguyen  Hannah     Nguyen
# 8      Carlos Garcia  Carlos     Garcia
# 9          Jisoo Kim   Jisoo        Kim
# 10               NaN    Tony        NaN

# %% [markdown]
# ## Removing Rows
# Drop rows by index:

# %%
df.drop(10, axis = 0, inplace=True)
# Removes the row with the specified index (use axis=0 for rows).

# %%
df
# Out:
#                email_address   age          Profession    Company  Score  \
# 0  ashishkhanagwal@gmail.com  24.0         AI Engineer       Meta   85.0
# 1     coreyschafar@gmail.com  27.0               Tutor    YouTube   90.0
# 2         timdavid@gmail.com  26.0  Software Developer     Google   88.0
# 3       meerapatel@gmail.com  25.0      Data Scientist  Microsoft   92.0
# 4       arjunsingh@gmail.com  29.0     Product Manager     Amazon   89.0
# 5   sophiawilliams@gmail.com  31.0         UX Designer      Apple   87.0
# 6        liambrown@gmail.com  28.0     DevOps Engineer    Netflix   91.0
# 7     hannahnguyen@gmail.com  24.0    Research Analyst      Tesla   86.0
# 8     carlosgarcia@gmail.com  32.0   Systems Architect        IBM   93.0
# 9         jisookim@gmail.com  26.0         ML Engineer     OpenAI   95.0
#
#           full name   first       last
# 0  Ashish Khanagwal  Ashish  Khanagwal
# 1    Corey Anderson   Corey   Anderson
# 2          John Doe    John        Doe
# 3       Meera Patel   Meera      Patel
# 4       Arjun Singh   Arjun      Singh
# 5   Sophia Williams  Sophia   Williams
# 6        Liam Brown    Liam      Brown
# 7     Hannah Nguyen  Hannah     Nguyen
# 8     Carlos Garcia  Carlos     Garcia
# 9         Jisoo Kim   Jisoo        Kim

# %% [markdown]
# # Drop multiple rows by index:
# `df.drop([0, 2], axis=0, inplace=True)`

# %% [markdown]
# ## Adding two DataFrames
# ### 1. Combine by Adding Rows (pd.concat)
# Use case: You want one DataFrame under the other, with the same columns.

# %%
people = {
  'first': ['Tony', 'Steve'],
  'last' : ['Stark', 'Rogers'],
  'email_address': ['tonystark@avenge.com', 'steverogers@avenge.com']
}

df2 = pd.DataFrame(people)
df2
# Out:
#    first    last           email_address
# 0   Tony   Stark    tonystark@avenge.com
# 1  Steve  Rogers  steverogers@avenge.com

# %%
df = pd.concat([df, df2], ignore_index=True)
df
# Out:
#                 email_address   age          Profession    Company  Score  \
# 0   ashishkhanagwal@gmail.com  24.0         AI Engineer       Meta   85.0
# 1      coreyschafar@gmail.com  27.0               Tutor    YouTube   90.0
# 2          timdavid@gmail.com  26.0  Software Developer     Google   88.0
# 3        meerapatel@gmail.com  25.0      Data Scientist  Microsoft   92.0
# 4        arjunsingh@gmail.com  29.0     Product Manager     Amazon   89.0
# 5    sophiawilliams@gmail.com  31.0         UX Designer      Apple   87.0
# 6         liambrown@gmail.com  28.0     DevOps Engineer    Netflix   91.0
# 7      hannahnguyen@gmail.com  24.0    Research Analyst      Tesla   86.0
# 8      carlosgarcia@gmail.com  32.0   Systems Architect        IBM   93.0
# 9          jisookim@gmail.com  26.0         ML Engineer     OpenAI   95.0
# 10       tonystark@avenge.com   NaN                 NaN        NaN    NaN
# 11     steverogers@avenge.com   NaN                 NaN        NaN    NaN
#
#            full name   first       last
# 0   Ashish Khanagwal  Ashish  Khanagwal
# 1     Corey Anderson   Corey   Anderson
# 2           John Doe    John        Doe
# 3        Meera Patel   Meera      Patel
# 4        Arjun Singh   Arjun      Singh
# 5    Sophia Williams  Sophia   Williams
# 6         Liam Brown    Liam      Brown
# 7      Hannah Nguyen  Hannah     Nguyen
# 8      Carlos Garcia  Carlos     Garcia
# 9          Jisoo Kim   Jisoo        Kim
# 10               NaN    Tony      Stark
# 11               NaN   Steve     Rogers

# %% [markdown]
# ## Sorting Data
# ### Sort by values
# - Sort a DataFrame by one column:

# %%
df.sort_values(by='age') # In Ascending order
# df.sort_values(by='age', ascending=False) # In Descending order
# Out:
#                 email_address   age          Profession    Company  Score  \
# 0   ashishkhanagwal@gmail.com  24.0         AI Engineer       Meta   85.0
# 7      hannahnguyen@gmail.com  24.0    Research Analyst      Tesla   86.0
# 3        meerapatel@gmail.com  25.0      Data Scientist  Microsoft   92.0
# 2          timdavid@gmail.com  26.0  Software Developer     Google   88.0
# 9          jisookim@gmail.com  26.0         ML Engineer     OpenAI   95.0
# 1      coreyschafar@gmail.com  27.0               Tutor    YouTube   90.0
# 6         liambrown@gmail.com  28.0     DevOps Engineer    Netflix   91.0
# 4        arjunsingh@gmail.com  29.0     Product Manager     Amazon   89.0
# 5    sophiawilliams@gmail.com  31.0         UX Designer      Apple   87.0
# 8      carlosgarcia@gmail.com  32.0   Systems Architect        IBM   93.0
# 10       tonystark@avenge.com   NaN                 NaN        NaN    NaN
# 11     steverogers@avenge.com   NaN                 NaN        NaN    NaN
#
#            full name   first       last
# 0   Ashish Khanagwal  Ashish  Khanagwal
# 7      Hannah Nguyen  Hannah     Nguyen
# 3        Meera Patel   Meera      Patel
# 2           John Doe    John        Doe
# 9          Jisoo Kim   Jisoo        Kim
# 1     Corey Anderson   Corey   Anderson
# 6         Liam Brown    Liam      Brown
# 4        Arjun Singh   Arjun      Singh
# 5    Sophia Williams  Sophia   Williams
# 8      Carlos Garcia  Carlos     Garcia
# 10               NaN    Tony      Stark
# 11               NaN   Steve     Rogers

# %% [markdown]
# ## Sort by multiple columns with different orders:

# %%
df.sort_values(by=['age', 'Score'], ascending=[True, False])
# First sorts by age, then within same age sort by score high->low.
# Out:
#                 email_address   age          Profession    Company  Score  \
# 7      hannahnguyen@gmail.com  24.0    Research Analyst      Tesla   86.0
# 0   ashishkhanagwal@gmail.com  24.0         AI Engineer       Meta   85.0
# 3        meerapatel@gmail.com  25.0      Data Scientist  Microsoft   92.0
# 9          jisookim@gmail.com  26.0         ML Engineer     OpenAI   95.0
# 2          timdavid@gmail.com  26.0  Software Developer     Google   88.0
# 1      coreyschafar@gmail.com  27.0               Tutor    YouTube   90.0
# 6         liambrown@gmail.com  28.0     DevOps Engineer    Netflix   91.0
# 4        arjunsingh@gmail.com  29.0     Product Manager     Amazon   89.0
# 5    sophiawilliams@gmail.com  31.0         UX Designer      Apple   87.0
# 8      carlosgarcia@gmail.com  32.0   Systems Architect        IBM   93.0
# 10       tonystark@avenge.com   NaN                 NaN        NaN    NaN
# 11     steverogers@avenge.com   NaN                 NaN        NaN    NaN
#
#            full name   first       last
# 7      Hannah Nguyen  Hannah     Nguyen
# 0   Ashish Khanagwal  Ashish  Khanagwal
# 3        Meera Patel   Meera      Patel
# 9          Jisoo Kim   Jisoo        Kim
# 2           John Doe    John        Doe
# 1     Corey Anderson   Corey   Anderson
# 6         Liam Brown    Liam      Brown
# 4        Arjun Singh   Arjun      Singh
# 5    Sophia Williams  Sophia   Williams
# 8      Carlos Garcia  Carlos     Garcia
# 10               NaN    Tony      Stark
# 11               NaN   Steve     Rogers

# %%
df.sort_values(by=['last', 'first'], ascending = [False, True], inplace=True)

# %%
df
# Out:
#                 email_address   age          Profession    Company  Score  \
# 5    sophiawilliams@gmail.com  31.0         UX Designer      Apple   87.0
# 10       tonystark@avenge.com   NaN                 NaN        NaN    NaN
# 4        arjunsingh@gmail.com  29.0     Product Manager     Amazon   89.0
# 11     steverogers@avenge.com   NaN                 NaN        NaN    NaN
# 3        meerapatel@gmail.com  25.0      Data Scientist  Microsoft   92.0
# 7      hannahnguyen@gmail.com  24.0    Research Analyst      Tesla   86.0
# 9          jisookim@gmail.com  26.0         ML Engineer     OpenAI   95.0
# 0   ashishkhanagwal@gmail.com  24.0         AI Engineer       Meta   85.0
# 8      carlosgarcia@gmail.com  32.0   Systems Architect        IBM   93.0
# 2          timdavid@gmail.com  26.0  Software Developer     Google   88.0
# 6         liambrown@gmail.com  28.0     DevOps Engineer    Netflix   91.0
# 1      coreyschafar@gmail.com  27.0               Tutor    YouTube   90.0
#
#            full name   first       last
# 5    Sophia Williams  Sophia   Williams
# 10               NaN    Tony      Stark
# 4        Arjun Singh   Arjun      Singh
# 11               NaN   Steve     Rogers
# 3        Meera Patel   Meera      Patel
# 7      Hannah Nguyen  Hannah     Nguyen
# 9          Jisoo Kim   Jisoo        Kim
# 0   Ashish Khanagwal  Ashish  Khanagwal
# 8      Carlos Garcia  Carlos     Garcia
# 2           John Doe    John        Doe
# 6         Liam Brown    Liam      Brown
# 1     Corey Anderson   Corey   Anderson

# %%
# In order to sort a specific series, we can do like this:-
df['first'].sort_values()
# Out:
# 4      Arjun
# 0     Ashish
# 8     Carlos
# 1      Corey
# 7     Hannah
# 9      Jisoo
# 2       John
# 6       Liam
# 3      Meera
# 5     Sophia
# 11     Steve
# 10      Tony
# Name: first, dtype: object

# %% [markdown]
# ## Control missing values placement:
# - Moves NaN values to the top instead of the default bottom

# %%
df.sort_values(by='age', na_position='first')
# Out:
#                 email_address   age          Profession    Company  Score  \
# 10       tonystark@avenge.com   NaN                 NaN        NaN    NaN
# 11     steverogers@avenge.com   NaN                 NaN        NaN    NaN
# 7      hannahnguyen@gmail.com  24.0    Research Analyst      Tesla   86.0
# 0   ashishkhanagwal@gmail.com  24.0         AI Engineer       Meta   85.0
# 3        meerapatel@gmail.com  25.0      Data Scientist  Microsoft   92.0
# 9          jisookim@gmail.com  26.0         ML Engineer     OpenAI   95.0
# 2          timdavid@gmail.com  26.0  Software Developer     Google   88.0
# 1      coreyschafar@gmail.com  27.0               Tutor    YouTube   90.0
# 6         liambrown@gmail.com  28.0     DevOps Engineer    Netflix   91.0
# 4        arjunsingh@gmail.com  29.0     Product Manager     Amazon   89.0
# 5    sophiawilliams@gmail.com  31.0         UX Designer      Apple   87.0
# 8      carlosgarcia@gmail.com  32.0   Systems Architect        IBM   93.0
#
#            full name   first       last
# 10               NaN    Tony      Stark
# 11               NaN   Steve     Rogers
# 7      Hannah Nguyen  Hannah     Nguyen
# 0   Ashish Khanagwal  Ashish  Khanagwal
# 3        Meera Patel   Meera      Patel
# 9          Jisoo Kim   Jisoo        Kim
# 2           John Doe    John        Doe
# 1     Corey Anderson   Corey   Anderson
# 6         Liam Brown    Liam      Brown
# 4        Arjun Singh   Arjun      Singh
# 5    Sophia Williams  Sophia   Williams
# 8      Carlos Garcia  Carlos     Garcia

# %% [markdown]
# ## Ignore original index in the result:
# - Resets the index in the sorted output.

# %%
df.sort_values(by='age', ignore_index=True)
# Out:
#                 email_address   age          Profession    Company  Score  \
# 0      hannahnguyen@gmail.com  24.0    Research Analyst      Tesla   86.0
# 1   ashishkhanagwal@gmail.com  24.0         AI Engineer       Meta   85.0
# 2        meerapatel@gmail.com  25.0      Data Scientist  Microsoft   92.0
# 3          jisookim@gmail.com  26.0         ML Engineer     OpenAI   95.0
# 4          timdavid@gmail.com  26.0  Software Developer     Google   88.0
# 5      coreyschafar@gmail.com  27.0               Tutor    YouTube   90.0
# 6         liambrown@gmail.com  28.0     DevOps Engineer    Netflix   91.0
# 7        arjunsingh@gmail.com  29.0     Product Manager     Amazon   89.0
# 8    sophiawilliams@gmail.com  31.0         UX Designer      Apple   87.0
# 9      carlosgarcia@gmail.com  32.0   Systems Architect        IBM   93.0
# 10       tonystark@avenge.com   NaN                 NaN        NaN    NaN
# 11     steverogers@avenge.com   NaN                 NaN        NaN    NaN
#
#            full name   first       last
# 0      Hannah Nguyen  Hannah     Nguyen
# 1   Ashish Khanagwal  Ashish  Khanagwal
# 2        Meera Patel   Meera      Patel
# 3          Jisoo Kim   Jisoo        Kim
# 4           John Doe    John        Doe
# 5     Corey Anderson   Corey   Anderson
# 6         Liam Brown    Liam      Brown
# 7        Arjun Singh   Arjun      Singh
# 8    Sophia Williams  Sophia   Williams
# 9      Carlos Garcia  Carlos     Garcia
# 10               NaN    Tony      Stark
# 11               NaN   Steve     Rogers

# %% [markdown]
# ## Sort by index labels
# ### 1. Sort rows by index:

# %%
df.sort_index()
# Orders the DataFrame by its row labels
# Out:
#                 email_address   age          Profession    Company  Score  \
# 0   ashishkhanagwal@gmail.com  24.0         AI Engineer       Meta   85.0
# 1      coreyschafar@gmail.com  27.0               Tutor    YouTube   90.0
# 2          timdavid@gmail.com  26.0  Software Developer     Google   88.0
# 3        meerapatel@gmail.com  25.0      Data Scientist  Microsoft   92.0
# 4        arjunsingh@gmail.com  29.0     Product Manager     Amazon   89.0
# 5    sophiawilliams@gmail.com  31.0         UX Designer      Apple   87.0
# 6         liambrown@gmail.com  28.0     DevOps Engineer    Netflix   91.0
# 7      hannahnguyen@gmail.com  24.0    Research Analyst      Tesla   86.0
# 8      carlosgarcia@gmail.com  32.0   Systems Architect        IBM   93.0
# 9          jisookim@gmail.com  26.0         ML Engineer     OpenAI   95.0
# 10       tonystark@avenge.com   NaN                 NaN        NaN    NaN
# 11     steverogers@avenge.com   NaN                 NaN        NaN    NaN
#
#            full name   first       last
# 0   Ashish Khanagwal  Ashish  Khanagwal
# 1     Corey Anderson   Corey   Anderson
# 2           John Doe    John        Doe
# 3        Meera Patel   Meera      Patel
# 4        Arjun Singh   Arjun      Singh
# 5    Sophia Williams  Sophia   Williams
# 6         Liam Brown    Liam      Brown
# 7      Hannah Nguyen  Hannah     Nguyen
# 8      Carlos Garcia  Carlos     Garcia
# 9          Jisoo Kim   Jisoo        Kim
# 10               NaN    Tony      Stark
# 11               NaN   Steve     Rogers

# %% [markdown]
# ### 3. Sort columns by their names:

# %%
df.sort_index(axis=1)
# Pandas looks at the column names as strings and sorts them in ASCII/lexicographical order, not by any “logical order” you might expect.
# Out:
#       Company          Profession  Score   age              email_address  \
# 5       Apple         UX Designer   87.0  31.0   sophiawilliams@gmail.com
# 10        NaN                 NaN    NaN   NaN       tonystark@avenge.com
# 4      Amazon     Product Manager   89.0  29.0       arjunsingh@gmail.com
# 11        NaN                 NaN    NaN   NaN     steverogers@avenge.com
# 3   Microsoft      Data Scientist   92.0  25.0       meerapatel@gmail.com
# 7       Tesla    Research Analyst   86.0  24.0     hannahnguyen@gmail.com
# 9      OpenAI         ML Engineer   95.0  26.0         jisookim@gmail.com
# 0        Meta         AI Engineer   85.0  24.0  ashishkhanagwal@gmail.com
# 8         IBM   Systems Architect   93.0  32.0     carlosgarcia@gmail.com
# 2      Google  Software Developer   88.0  26.0         timdavid@gmail.com
# 6     Netflix     DevOps Engineer   91.0  28.0        liambrown@gmail.com
# 1     YouTube               Tutor   90.0  27.0     coreyschafar@gmail.com
#
#      first         full name       last
# 5   Sophia   Sophia Williams   Williams
# 10    Tony               NaN      Stark
# 4    Arjun       Arjun Singh      Singh
# 11   Steve               NaN     Rogers
# 3    Meera       Meera Patel      Patel
# 7   Hannah     Hannah Nguyen     Nguyen
# 9    Jisoo         Jisoo Kim        Kim
# 0   Ashish  Ashish Khanagwal  Khanagwal
# 8   Carlos     Carlos Garcia     Garcia
# 2     John          John Doe        Doe
# 6     Liam        Liam Brown      Brown
# 1    Corey    Corey Anderson   Anderson

# %% [markdown]
# ## Sort MultiIndex by specific level:
# - Sorts using a particular index level in a hierarchical index.

# %%
df.index
# Out:
# Index([5, 10, 4, 11, 3, 7, 9, 0, 8, 2, 6, 1], dtype='int64')

# %%
df.columns
# Out:
# Index(['email_address', 'age', 'Profession', 'Company', 'Score', 'full name',
#        'first', 'last'],
#       dtype='object')

# %% [markdown]
# ### `df.sort_index(level='')`
# ## What level means
# - level is used when your rows or columns have a MultiIndex (multiple levels of indexing).
# - It tells pandas: “Sort by this level of the index.”

# %%
df
# Out:
#                 email_address   age          Profession    Company  Score  \
# 5    sophiawilliams@gmail.com  31.0         UX Designer      Apple   87.0
# 10       tonystark@avenge.com   NaN                 NaN        NaN    NaN
# 4        arjunsingh@gmail.com  29.0     Product Manager     Amazon   89.0
# 11     steverogers@avenge.com   NaN                 NaN        NaN    NaN
# 3        meerapatel@gmail.com  25.0      Data Scientist  Microsoft   92.0
# 7      hannahnguyen@gmail.com  24.0    Research Analyst      Tesla   86.0
# 9          jisookim@gmail.com  26.0         ML Engineer     OpenAI   95.0
# 0   ashishkhanagwal@gmail.com  24.0         AI Engineer       Meta   85.0
# 8      carlosgarcia@gmail.com  32.0   Systems Architect        IBM   93.0
# 2          timdavid@gmail.com  26.0  Software Developer     Google   88.0
# 6         liambrown@gmail.com  28.0     DevOps Engineer    Netflix   91.0
# 1      coreyschafar@gmail.com  27.0               Tutor    YouTube   90.0
#
#            full name   first       last
# 5    Sophia Williams  Sophia   Williams
# 10               NaN    Tony      Stark
# 4        Arjun Singh   Arjun      Singh
# 11               NaN   Steve     Rogers
# 3        Meera Patel   Meera      Patel
# 7      Hannah Nguyen  Hannah     Nguyen
# 9          Jisoo Kim   Jisoo        Kim
# 0   Ashish Khanagwal  Ashish  Khanagwal
# 8      Carlos Garcia  Carlos     Garcia
# 2           John Doe    John        Doe
# 6         Liam Brown    Liam      Brown
# 1     Corey Anderson   Corey   Anderson

# %% [markdown]
# ## Grouping And Aggregating

# %%
df2 = pd.DataFrame({
    'Dept': ['A','A','B','B','B'],
    'Employee': ['x','y','u','v','w'],
    'Salary': [70, 80, 60, 50, 90],
    'Bonus': [7, 8, 6, 5, 9]
})

# %%
dept_grp = df2.groupby(['Dept'])

dept_grp['Employee'].count()

# Count rows per group: df.groupby('Dept')['Employee'].count() shows how many entries per department.
# Out:
# Dept
# A    2
# B    3
# Name: Employee, dtype: int64

# %%
# Multiple columns grouping: df.groupby(['Dept','Employee']).size() gives a frequency table of combinations.
df2.groupby(['Dept', 'Employee']).size()
# Out:
# Dept  Employee
# A     x           1
#       y           1
# B     u           1
#       v           1
#       w           1
# dtype: int64

# %%
# Single aggregation: df.groupby('Dept')['Salary'].mean() computes the average salary per department
dept_grp['Salary'].mean()
# Out:
# Dept
# A    75.000000
# B    66.666667
# Name: Salary, dtype: float64

# %%
# Multiple aggregations on one column:
dept_grp['Salary'].agg(['min', 'median', 'mean', 'max'])
# Out:
#       min  median       mean  max
# Dept
# A      70    75.0  75.000000   80
# B      50    60.0  66.666667   90

# %%
# Aggregations per column with dict:
# This allows per-column functions in one pass
dept_grp.agg({'Salary': 'mean', 'Bonus': 'sum'})
# Out:
#          Salary  Bonus
# Dept
# A     75.000000     15
# B     66.666667     20

# %%
# Named aggregations to control output names:
# Named syntax is concise and yields readable column names.
dept_grp.agg(avg_salary = ('Salary', 'mean'), top_bonus = ('Bonus', 'max'))
# Out:
#       avg_salary  top_bonus
# Dept
# A      75.000000          8
# B      66.666667          9
