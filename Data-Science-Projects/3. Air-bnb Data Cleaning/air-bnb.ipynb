# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Airbnb_Open_Data.csv', index_col='id')
# Out:
# /var/folders/zs/6h03lndj5114078br2jdh8380000gn/T/ipykernel_9750/4290526060.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Airbnb_Open_Data.csv', index_col='id')

# %%
df.head()
# Out:
#                                                      NAME      host id  \
# id
# 1001254                Clean & quiet apt home by the park  80014485718
# 1002102                             Skylit Midtown Castle  52335172823
# 1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 1002755                                               NaN  85098326012
# 1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#         host_identity_verified host name neighbourhood group neighbourhood  \
# id
# 1001254            unconfirmed  Madaline            Brooklyn    Kensington
# 1002102               verified     Jenna           Manhattan       Midtown
# 1002403                    NaN     Elise           Manhattan        Harlem
# 1002755            unconfirmed     Garry            Brooklyn  Clinton Hill
# 1003689               verified    Lyndon           Manhattan   East Harlem
#
#               lat      long        country country code instant_bookable  \
# id
# 1001254  40.64749 -73.97237  United States           US            False
# 1002102  40.75362 -73.98377  United States           US            False
# 1002403  40.80902 -73.94190  United States           US             True
# 1002755  40.68514 -73.95976  United States           US             True
# 1003689  40.79851 -73.94399  United States           US            False
#
#         cancellation_policy        room type  Construction year  price  \
# id
# 1001254              strict     Private room             2020.0  $966
# 1002102            moderate  Entire home/apt             2007.0  $142
# 1002403            flexible     Private room             2005.0  $620
# 1002755            moderate  Entire home/apt             2005.0  $368
# 1003689            moderate  Entire home/apt             2009.0  $204
#
#         service fee  minimum nights  number of reviews last review  \
# id
# 1001254       $193             10.0                9.0  10/19/2021
# 1002102        $28             30.0               45.0   5/21/2022
# 1002403       $124              3.0                0.0         NaN
# 1002755        $74             30.0              270.0    7/5/2019
# 1003689        $41             10.0                9.0  11/19/2018
#
#          reviews per month  review rate number  \
# id
# 1001254               0.21                 4.0
# 1002102               0.38                 4.0
# 1002403                NaN                 5.0
# 1002755               4.64                 4.0
# 1003689               0.10                 3.0
#
#          calculated host listings count  availability 365  \
# id
# 1001254                             6.0             286.0
# 1002102                             2.0             228.0
# 1002403                             1.0             352.0
# 1002755                             1.0             322.0
# 1003689                             1.0             289.0
#
#                                                house_rules license
# id
# 1001254  Clean up and treat the home the way you'd like...     NaN
# 1002102  Pet friendly but please confirm with me if the...     NaN
# 1002403  I encourage you to use my kitchen, cooking and...     NaN
# 1002755                                                NaN     NaN
# 1003689  Please no smoking in the house, porch or on th...     NaN

# %%
df.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
df
# Out:
#                                                      NAME      host id  \
# id
# 1001254                Clean & quiet apt home by the park  80014485718
# 1002102                             Skylit Midtown Castle  52335172823
# 1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 1002755                                               NaN  85098326012
# 1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                   ...          ...
# 6092437                        Spare room in Williamsburg  12312296767
# 6092990                     Best Location near Columbia U  77864383453
# 6093542                    Comfy, bright room in Brooklyn  69050334417
# 6094094                  Big Studio-One Stop from Midtown  11160591270
# 6094647                              585 sf Luxury Studio  68170633372
#
#         host_identity_verified    host name neighbourhood group  \
# id
# 1001254            unconfirmed     Madaline            Brooklyn
# 1002102               verified        Jenna           Manhattan
# 1002403                    NaN        Elise           Manhattan
# 1002755            unconfirmed        Garry            Brooklyn
# 1003689               verified       Lyndon           Manhattan
# ...                        ...          ...                 ...
# 6092437               verified         Krik            Brooklyn
# 6092990            unconfirmed        Mifan           Manhattan
# 6093542            unconfirmed        Megan            Brooklyn
# 6094094            unconfirmed  Christopher              Queens
# 6094647            unconfirmed      Rebecca           Manhattan
#
#                neighbourhood       lat      long        country country code  \
# id
# 1001254           Kensington  40.64749 -73.97237  United States           US
# 1002102              Midtown  40.75362 -73.98377  United States           US
# 1002403               Harlem  40.80902 -73.94190  United States           US
# 1002755         Clinton Hill  40.68514 -73.95976  United States           US
# 1003689          East Harlem  40.79851 -73.94399  United States           US
# ...                      ...       ...       ...            ...          ...
# 6092437         Williamsburg  40.70862 -73.94651  United States           US
# 6092990  Morningside Heights  40.80460 -73.96545  United States           US
# 6093542           Park Slope  40.67505 -73.98045  United States           US
# 6094094     Long Island City  40.74989 -73.93777  United States           US
# 6094647      Upper West Side  40.76807 -73.98342  United States           US
#
#         instant_bookable cancellation_policy        room type  \
# id
# 1001254            False              strict     Private room
# 1002102            False            moderate  Entire home/apt
# 1002403             True            flexible     Private room
# 1002755             True            moderate  Entire home/apt
# 1003689            False            moderate  Entire home/apt
# ...                  ...                 ...              ...
# 6092437            False            flexible     Private room
# 6092990             True            moderate     Private room
# 6093542             True            moderate     Private room
# 6094094             True              strict  Entire home/apt
# 6094647            False            flexible  Entire home/apt
#
#          Construction year    price service fee  minimum nights  \
# id
# 1001254             2020.0    $966        $193             10.0
# 1002102             2007.0    $142         $28             30.0
# 1002403             2005.0    $620        $124              3.0
# 1002755             2005.0    $368         $74             30.0
# 1003689             2009.0    $204         $41             10.0
# ...                    ...      ...         ...             ...
# 6092437             2003.0    $844        $169              1.0
# 6092990             2016.0    $837        $167              1.0
# 6093542             2009.0    $988        $198              3.0
# 6094094             2015.0    $546        $109              2.0
# 6094647             2010.0  $1,032        $206              1.0
#
#          number of reviews last review  reviews per month  review rate number  \
# id
# 1001254                9.0  10/19/2021               0.21                 4.0
# 1002102               45.0   5/21/2022               0.38                 4.0
# 1002403                0.0         NaN                NaN                 5.0
# 1002755              270.0    7/5/2019               4.64                 4.0
# 1003689                9.0  11/19/2018               0.10                 3.0
# ...                    ...         ...                ...                 ...
# 6092437                0.0         NaN                NaN                 3.0
# 6092990                1.0    7/6/2015               0.02                 2.0
# 6093542                0.0         NaN                NaN                 5.0
# 6094094                5.0  10/11/2015               0.10                 3.0
# 6094647                0.0         NaN                NaN                 3.0
#
#          calculated host listings count  availability 365  \
# id
# 1001254                             6.0             286.0
# 1002102                             2.0             228.0
# 1002403                             1.0             352.0
# 1002755                             1.0             322.0
# 1003689                             1.0             289.0
# ...                                 ...               ...
# 6092437                             1.0             227.0
# 6092990                             2.0             395.0
# 6093542                             1.0             342.0
# 6094094                             1.0             386.0
# 6094647                             1.0              69.0
#
#                                                house_rules license
# id
# 1001254  Clean up and treat the home the way you'd like...     NaN
# 1002102  Pet friendly but please confirm with me if the...     NaN
# 1002403  I encourage you to use my kitchen, cooking and...     NaN
# 1002755                                                NaN     NaN
# 1003689  Please no smoking in the house, porch or on th...     NaN
# ...                                                    ...     ...
# 6092437  No Smoking No Parties or Events of any kind Pl...     NaN
# 6092990  House rules: Guests agree to the following ter...     NaN
# 6093542                                                NaN     NaN
# 6094094                                                NaN     NaN
# 6094647                                                NaN     NaN
#
# [102599 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102599 entries, 1001254 to 6094647
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   NAME                            102349 non-null  object
#  1   host id                         102599 non-null  int64
#  2   host_identity_verified          102310 non-null  object
#  3   host name                       102193 non-null  object
#  4   neighbourhood group             102570 non-null  object
#  5   neighbourhood                   102583 non-null  object
#  6   lat                             102591 non-null  float64
#  7   long                            102591 non-null  float64
#  8   country                         102067 non-null  object
#  9   country code                    102468 non-null  object
#  10  instant_bookable                102494 non-null  object
#  11  cancellation_policy             102523 non-null  object
#  12  room type                       102599 non-null  object
#  13  Construction year               102385 non-null  float64
#  14  price                           102352 non-null  object
#  15  service fee                     102326 non-null  object
#  16  minimum nights                  102190 non-null  float64
#  17  number of reviews               102416 non-null  float64
#  18  last review                     86706 non-null   object
#  19  reviews per month               86720 non-null   float64
#  20  review rate number              102273 non-null  float64
#  21  calculated host listings count  102280 non-null  float64
#  22  availability 365                102151 non-null  float64
#  23  house_rules                     50468 non-null   object
#  24  license                         2 non-null       object
# dtypes: float64(9), int64(1), object(15)
# memory usage: 20.4+ MB

# %%
df.tail()
# Out:
#                                      NAME      host id host_identity_verified  \
# id
# 6092437        Spare room in Williamsburg  12312296767               verified
# 6092990     Best Location near Columbia U  77864383453            unconfirmed
# 6093542    Comfy, bright room in Brooklyn  69050334417            unconfirmed
# 6094094  Big Studio-One Stop from Midtown  11160591270            unconfirmed
# 6094647              585 sf Luxury Studio  68170633372            unconfirmed
#
#            host name neighbourhood group        neighbourhood       lat  \
# id
# 6092437         Krik            Brooklyn         Williamsburg  40.70862
# 6092990        Mifan           Manhattan  Morningside Heights  40.80460
# 6093542        Megan            Brooklyn           Park Slope  40.67505
# 6094094  Christopher              Queens     Long Island City  40.74989
# 6094647      Rebecca           Manhattan      Upper West Side  40.76807
#
#              long        country country code instant_bookable  \
# id
# 6092437 -73.94651  United States           US            False
# 6092990 -73.96545  United States           US             True
# 6093542 -73.98045  United States           US             True
# 6094094 -73.93777  United States           US             True
# 6094647 -73.98342  United States           US            False
#
#         cancellation_policy        room type  Construction year    price  \
# id
# 6092437            flexible     Private room             2003.0    $844
# 6092990            moderate     Private room             2016.0    $837
# 6093542            moderate     Private room             2009.0    $988
# 6094094              strict  Entire home/apt             2015.0    $546
# 6094647            flexible  Entire home/apt             2010.0  $1,032
#
#         service fee  minimum nights  number of reviews last review  \
# id
# 6092437       $169              1.0                0.0         NaN
# 6092990       $167              1.0                1.0    7/6/2015
# 6093542       $198              3.0                0.0         NaN
# 6094094       $109              2.0                5.0  10/11/2015
# 6094647       $206              1.0                0.0         NaN
#
#          reviews per month  review rate number  \
# id
# 6092437                NaN                 3.0
# 6092990               0.02                 2.0
# 6093542                NaN                 5.0
# 6094094               0.10                 3.0
# 6094647                NaN                 3.0
#
#          calculated host listings count  availability 365  \
# id
# 6092437                             1.0             227.0
# 6092990                             2.0             395.0
# 6093542                             1.0             342.0
# 6094094                             1.0             386.0
# 6094647                             1.0              69.0
#
#                                                house_rules license
# id
# 6092437  No Smoking No Parties or Events of any kind Pl...     NaN
# 6092990  House rules: Guests agree to the following ter...     NaN
# 6093542                                                NaN     NaN
# 6094094                                                NaN     NaN
# 6094647                                                NaN     NaN

# %%
pd.set_option('display.max_columns', 25)

# %%
df
# Out:
#                                                      NAME      host id  \
# id
# 1001254                Clean & quiet apt home by the park  80014485718
# 1002102                             Skylit Midtown Castle  52335172823
# 1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 1002755                                               NaN  85098326012
# 1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                   ...          ...
# 6092437                        Spare room in Williamsburg  12312296767
# 6092990                     Best Location near Columbia U  77864383453
# 6093542                    Comfy, bright room in Brooklyn  69050334417
# 6094094                  Big Studio-One Stop from Midtown  11160591270
# 6094647                              585 sf Luxury Studio  68170633372
#
#         host_identity_verified    host name neighbourhood group  \
# id
# 1001254            unconfirmed     Madaline            Brooklyn
# 1002102               verified        Jenna           Manhattan
# 1002403                    NaN        Elise           Manhattan
# 1002755            unconfirmed        Garry            Brooklyn
# 1003689               verified       Lyndon           Manhattan
# ...                        ...          ...                 ...
# 6092437               verified         Krik            Brooklyn
# 6092990            unconfirmed        Mifan           Manhattan
# 6093542            unconfirmed        Megan            Brooklyn
# 6094094            unconfirmed  Christopher              Queens
# 6094647            unconfirmed      Rebecca           Manhattan
#
#                neighbourhood       lat      long        country country code  \
# id
# 1001254           Kensington  40.64749 -73.97237  United States           US
# 1002102              Midtown  40.75362 -73.98377  United States           US
# 1002403               Harlem  40.80902 -73.94190  United States           US
# 1002755         Clinton Hill  40.68514 -73.95976  United States           US
# 1003689          East Harlem  40.79851 -73.94399  United States           US
# ...                      ...       ...       ...            ...          ...
# 6092437         Williamsburg  40.70862 -73.94651  United States           US
# 6092990  Morningside Heights  40.80460 -73.96545  United States           US
# 6093542           Park Slope  40.67505 -73.98045  United States           US
# 6094094     Long Island City  40.74989 -73.93777  United States           US
# 6094647      Upper West Side  40.76807 -73.98342  United States           US
#
#         instant_bookable cancellation_policy        room type  \
# id
# 1001254            False              strict     Private room
# 1002102            False            moderate  Entire home/apt
# 1002403             True            flexible     Private room
# 1002755             True            moderate  Entire home/apt
# 1003689            False            moderate  Entire home/apt
# ...                  ...                 ...              ...
# 6092437            False            flexible     Private room
# 6092990             True            moderate     Private room
# 6093542             True            moderate     Private room
# 6094094             True              strict  Entire home/apt
# 6094647            False            flexible  Entire home/apt
#
#          Construction year    price service fee  minimum nights  \
# id
# 1001254             2020.0    $966        $193             10.0
# 1002102             2007.0    $142         $28             30.0
# 1002403             2005.0    $620        $124              3.0
# 1002755             2005.0    $368         $74             30.0
# 1003689             2009.0    $204         $41             10.0
# ...                    ...      ...         ...             ...
# 6092437             2003.0    $844        $169              1.0
# 6092990             2016.0    $837        $167              1.0
# 6093542             2009.0    $988        $198              3.0
# 6094094             2015.0    $546        $109              2.0
# 6094647             2010.0  $1,032        $206              1.0
#
#          number of reviews last review  reviews per month  review rate number  \
# id
# 1001254                9.0  10/19/2021               0.21                 4.0
# 1002102               45.0   5/21/2022               0.38                 4.0
# 1002403                0.0         NaN                NaN                 5.0
# 1002755              270.0    7/5/2019               4.64                 4.0
# 1003689                9.0  11/19/2018               0.10                 3.0
# ...                    ...         ...                ...                 ...
# 6092437                0.0         NaN                NaN                 3.0
# 6092990                1.0    7/6/2015               0.02                 2.0
# 6093542                0.0         NaN                NaN                 5.0
# 6094094                5.0  10/11/2015               0.10                 3.0
# 6094647                0.0         NaN                NaN                 3.0
#
#          calculated host listings count  availability 365  \
# id
# 1001254                             6.0             286.0
# 1002102                             2.0             228.0
# 1002403                             1.0             352.0
# 1002755                             1.0             322.0
# 1003689                             1.0             289.0
# ...                                 ...               ...
# 6092437                             1.0             227.0
# 6092990                             2.0             395.0
# 6093542                             1.0             342.0
# 6094094                             1.0             386.0
# 6094647                             1.0              69.0
#
#                                                house_rules license
# id
# 1001254  Clean up and treat the home the way you'd like...     NaN
# 1002102  Pet friendly but please confirm with me if the...     NaN
# 1002403  I encourage you to use my kitchen, cooking and...     NaN
# 1002755                                                NaN     NaN
# 1003689  Please no smoking in the house, porch or on th...     NaN
# ...                                                    ...     ...
# 6092437  No Smoking No Parties or Events of any kind Pl...     NaN
# 6092990  House rules: Guests agree to the following ter...     NaN
# 6093542                                                NaN     NaN
# 6094094                                                NaN     NaN
# 6094647                                                NaN     NaN
#
# [102599 rows x 25 columns]

# %%
name = df['NAME']
name
# Out:
# id
# 1001254                  Clean & quiet apt home by the park
# 1002102                               Skylit Midtown Castle
# 1002403                 THE VILLAGE OF HARLEM....NEW YORK !
# 1002755                                                 NaN
# 1003689    Entire Apt: Spacious Studio/Loft by central park
#                                  ...
# 6092437                          Spare room in Williamsburg
# 6092990                       Best Location near Columbia U
# 6093542                      Comfy, bright room in Brooklyn
# 6094094                    Big Studio-One Stop from Midtown
# 6094647                                585 sf Luxury Studio
# Name: NAME, Length: 102599, dtype: object

# %%
subset = df[['NAME', 'country']]
subset
# Out:
#                                                      NAME        country
# id
# 1001254                Clean & quiet apt home by the park  United States
# 1002102                             Skylit Midtown Castle  United States
# 1002403               THE VILLAGE OF HARLEM....NEW YORK !  United States
# 1002755                                               NaN  United States
# 1003689  Entire Apt: Spacious Studio/Loft by central park  United States
# ...                                                   ...            ...
# 6092437                        Spare room in Williamsburg  United States
# 6092990                     Best Location near Columbia U  United States
# 6093542                    Comfy, bright room in Brooklyn  United States
# 6094094                  Big Studio-One Stop from Midtown  United States
# 6094647                              585 sf Luxury Studio  United States
#
# [102599 rows x 2 columns]

# %%
df.iloc[0:5]
# Out:
#                                                      NAME      host id  \
# id
# 1001254                Clean & quiet apt home by the park  80014485718
# 1002102                             Skylit Midtown Castle  52335172823
# 1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 1002755                                               NaN  85098326012
# 1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#         host_identity_verified host name neighbourhood group neighbourhood  \
# id
# 1001254            unconfirmed  Madaline            Brooklyn    Kensington
# 1002102               verified     Jenna           Manhattan       Midtown
# 1002403                    NaN     Elise           Manhattan        Harlem
# 1002755            unconfirmed     Garry            Brooklyn  Clinton Hill
# 1003689               verified    Lyndon           Manhattan   East Harlem
#
#               lat      long        country country code instant_bookable  \
# id
# 1001254  40.64749 -73.97237  United States           US            False
# 1002102  40.75362 -73.98377  United States           US            False
# 1002403  40.80902 -73.94190  United States           US             True
# 1002755  40.68514 -73.95976  United States           US             True
# 1003689  40.79851 -73.94399  United States           US            False
#
#         cancellation_policy        room type  Construction year  price  \
# id
# 1001254              strict     Private room             2020.0  $966
# 1002102            moderate  Entire home/apt             2007.0  $142
# 1002403            flexible     Private room             2005.0  $620
# 1002755            moderate  Entire home/apt             2005.0  $368
# 1003689            moderate  Entire home/apt             2009.0  $204
#
#         service fee  minimum nights  number of reviews last review  \
# id
# 1001254       $193             10.0                9.0  10/19/2021
# 1002102        $28             30.0               45.0   5/21/2022
# 1002403       $124              3.0                0.0         NaN
# 1002755        $74             30.0              270.0    7/5/2019
# 1003689        $41             10.0                9.0  11/19/2018
#
#          reviews per month  review rate number  \
# id
# 1001254               0.21                 4.0
# 1002102               0.38                 4.0
# 1002403                NaN                 5.0
# 1002755               4.64                 4.0
# 1003689               0.10                 3.0
#
#          calculated host listings count  availability 365  \
# id
# 1001254                             6.0             286.0
# 1002102                             2.0             228.0
# 1002403                             1.0             352.0
# 1002755                             1.0             322.0
# 1003689                             1.0             289.0
#
#                                                house_rules license
# id
# 1001254  Clean up and treat the home the way you'd like...     NaN
# 1002102  Pet friendly but please confirm with me if the...     NaN
# 1002403  I encourage you to use my kitchen, cooking and...     NaN
# 1002755                                                NaN     NaN
# 1003689  Please no smoking in the house, porch or on th...     NaN

# %%
df.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
Countries = ['United States', 'India', 'United Kingdom', 'Germany']
filt = df['country'].isin(Countries)
df.loc[filt, 'country']
# Out:
# id
# 1001254    United States
# 1002102    United States
# 1002403    United States
# 1002755    United States
# 1003689    United States
#                ...
# 6092437    United States
# 6092990    United States
# 6093542    United States
# 6094094    United States
# 6094647    United States
# Name: country, Length: 102067, dtype: object

# %%
df.sort_values(by=['country'], ascending = [True], inplace=True)
df['country'].head(20)
# Out:
# id
# 1001254     United States
# 38763192    United States
# 38762639    United States
# 38762087    United States
# 38761535    United States
# 38760982    United States
# 38760430    United States
# 38759878    United States
# 38759326    United States
# 38758773    United States
# 38763744    United States
# 38758221    United States
# 38757116    United States
# 38756564    United States
# 38756012    United States
# 38755459    United States
# 38754907    United States
# 38754355    United States
# 38753803    United States
# 38753250    United States
# Name: country, dtype: object

# %%
df.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
columns_to_keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review']

columns_to_drop = ['reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license']

# %%
len(columns_to_keep)
# Out:
# 19

# %%
len(columns_to_drop)
# Out:
# 6

# %% [markdown]
# ## 1st method -> Data filtering

# %%
data = df[columns_to_keep]

# %%
data.shape
# Out:
# (102599, 19)

# %%
data
# Out:
#                                                        NAME      host id  \
# id
# 1001254                  Clean & quiet apt home by the park  80014485718
# 38763192  Big One Bedroom Directly Across from Central P...  36257056231
# 38762639                 Affordable 2 Bedroom on the UES!!!  83771419475
# 38762087                            Charming 1 br apartment   8856169091
# 38761535     Masterbed w/private bath nr G train in BedStuy  51789425655
# ...                                                     ...          ...
# 56986882        Charming Park Slope Apt (fits up to 6 ppl)!   2778317625
# 56987435                           Studio with amazing view  25057683830
# 56987987        Private apartment in new Brooklyn building!  35509233859
# 56988539        UES(mini loft)Clean flex room (Female Only)  76384585618
# 56989092                        Luxury Loft in Williamsburg   5156600288
#
#          host_identity_verified         host name neighbourhood group  \
# id
# 1001254             unconfirmed          Madaline            Brooklyn
# 38763192            unconfirmed             Shaye           Manhattan
# 38762639            unconfirmed               Zoe           Manhattan
# 38762087               verified            Andrew            Brooklyn
# 38761535            unconfirmed            Vandra            Brooklyn
# ...                         ...               ...                 ...
# 56986882            unconfirmed             Julia            Brooklyn
# 56987435            unconfirmed          Carolann           Manhattan
# 56987987            unconfirmed  Steven & Melissa            Brooklyn
# 56988539               verified             Eun M           Manhattan
# 56989092               verified             Aaron            Brooklyn
#
#                neighbourhood       lat      long        country country code  \
# id
# 1001254           Kensington  40.64749 -73.97237  United States           US
# 38763192     Upper West Side  40.79982 -73.96058  United States           US
# 38762639     Upper East Side  40.76644 -73.95486  United States           US
# 38762087            Bushwick  40.70587 -73.92358  United States           US
# 38761535  Bedford-Stuyvesant  40.68797 -73.95920  United States           US
# ...                      ...       ...       ...            ...          ...
# 56986882     Windsor Terrace  40.66063 -73.98348            NaN           US
# 56987435  Financial District  40.70588 -74.01590            NaN           US
# 56987987  Bedford-Stuyvesant  40.68438 -73.95299            NaN           US
# 56988539     Upper East Side  40.77759 -73.95321            NaN           US
# 56989092        Williamsburg  40.71218 -73.96048            NaN           US
#
#          instant_bookable cancellation_policy        room type  \
# id
# 1001254             False              strict     Private room
# 38763192            False              strict  Entire home/apt
# 38762639             True            moderate  Entire home/apt
# 38762087             True              strict  Entire home/apt
# 38761535             True            moderate     Private room
# ...                   ...                 ...              ...
# 56986882            False            moderate  Entire home/apt
# 56987435             True              strict  Entire home/apt
# 56987987            False              strict  Entire home/apt
# 56988539            False              strict     Private room
# 56989092            False              strict  Entire home/apt
#
#           Construction year    price service fee  minimum nights  \
# id
# 1001254              2020.0    $966        $193             10.0
# 38763192             2013.0    $286         $57              2.0
# 38762639             2010.0    $858        $172              3.0
# 38762087             2013.0    $766        $153              2.0
# 38761535             2021.0    $198         $40              1.0
# ...                     ...      ...         ...             ...
# 56986882             2004.0    $765        $153              3.0
# 56987435             2010.0    $201         $40            300.0
# 56987987             2019.0    $132         $26              2.0
# 56988539             2022.0    $940        $188              1.0
# 56989092             2020.0  $1,020        $204              3.0
#
#           number of reviews last review
# id
# 1001254                 9.0  10/19/2021
# 38763192                1.0   9/10/2017
# 38762639                3.0   9/28/2017
# 38762087               13.0   4/15/2018
# 38761535                0.0         NaN
# ...                     ...         ...
# 56986882                0.0         NaN
# 56987435                0.0         NaN
# 56987987               33.0   5/22/2019
# 56988539              133.0   6/19/2019
# 56989092                8.0   8/26/2018
#
# [102599 rows x 19 columns]

# %% [markdown]
# ## 2nd method -> Dropping columns

# %%
df.drop(columns = columns_to_drop, inplace=True)

# %%
df.shape
# Out:
# (102599, 19)

# %% [markdown]
# ## Renaming column

# %%
df.rename(columns = {"NAME" : "Name"}, inplace = True)

# %%
data.rename(columns = {"NAME": "Name"}, inplace = True)

# %%
data
# Out:
#                                                        Name      host id  \
# id
# 1001254                  Clean & quiet apt home by the park  80014485718
# 38763192  Big One Bedroom Directly Across from Central P...  36257056231
# 38762639                 Affordable 2 Bedroom on the UES!!!  83771419475
# 38762087                            Charming 1 br apartment   8856169091
# 38761535     Masterbed w/private bath nr G train in BedStuy  51789425655
# ...                                                     ...          ...
# 56986882        Charming Park Slope Apt (fits up to 6 ppl)!   2778317625
# 56987435                           Studio with amazing view  25057683830
# 56987987        Private apartment in new Brooklyn building!  35509233859
# 56988539        UES(mini loft)Clean flex room (Female Only)  76384585618
# 56989092                        Luxury Loft in Williamsburg   5156600288
#
#          host_identity_verified         host name neighbourhood group  \
# id
# 1001254             unconfirmed          Madaline            Brooklyn
# 38763192            unconfirmed             Shaye           Manhattan
# 38762639            unconfirmed               Zoe           Manhattan
# 38762087               verified            Andrew            Brooklyn
# 38761535            unconfirmed            Vandra            Brooklyn
# ...                         ...               ...                 ...
# 56986882            unconfirmed             Julia            Brooklyn
# 56987435            unconfirmed          Carolann           Manhattan
# 56987987            unconfirmed  Steven & Melissa            Brooklyn
# 56988539               verified             Eun M           Manhattan
# 56989092               verified             Aaron            Brooklyn
#
#                neighbourhood       lat      long        country country code  \
# id
# 1001254           Kensington  40.64749 -73.97237  United States           US
# 38763192     Upper West Side  40.79982 -73.96058  United States           US
# 38762639     Upper East Side  40.76644 -73.95486  United States           US
# 38762087            Bushwick  40.70587 -73.92358  United States           US
# 38761535  Bedford-Stuyvesant  40.68797 -73.95920  United States           US
# ...                      ...       ...       ...            ...          ...
# 56986882     Windsor Terrace  40.66063 -73.98348            NaN           US
# 56987435  Financial District  40.70588 -74.01590            NaN           US
# 56987987  Bedford-Stuyvesant  40.68438 -73.95299            NaN           US
# 56988539     Upper East Side  40.77759 -73.95321            NaN           US
# 56989092        Williamsburg  40.71218 -73.96048            NaN           US
#
#          instant_bookable cancellation_policy        room type  \
# id
# 1001254             False              strict     Private room
# 38763192            False              strict  Entire home/apt
# 38762639             True            moderate  Entire home/apt
# 38762087             True              strict  Entire home/apt
# 38761535             True            moderate     Private room
# ...                   ...                 ...              ...
# 56986882            False            moderate  Entire home/apt
# 56987435             True              strict  Entire home/apt
# 56987987            False              strict  Entire home/apt
# 56988539            False              strict     Private room
# 56989092            False              strict  Entire home/apt
#
#           Construction year    price service fee  minimum nights  \
# id
# 1001254              2020.0    $966        $193             10.0
# 38763192             2013.0    $286         $57              2.0
# 38762639             2010.0    $858        $172              3.0
# 38762087             2013.0    $766        $153              2.0
# 38761535             2021.0    $198         $40              1.0
# ...                     ...      ...         ...             ...
# 56986882             2004.0    $765        $153              3.0
# 56987435             2010.0    $201         $40            300.0
# 56987987             2019.0    $132         $26              2.0
# 56988539             2022.0    $940        $188              1.0
# 56989092             2020.0  $1,020        $204              3.0
#
#           number of reviews last review
# id
# 1001254                 9.0  10/19/2021
# 38763192                1.0   9/10/2017
# 38762639                3.0   9/28/2017
# 38762087               13.0   4/15/2018
# 38761535                0.0         NaN
# ...                     ...         ...
# 56986882                0.0         NaN
# 56987435                0.0         NaN
# 56987987               33.0   5/22/2019
# 56988539              133.0   6/19/2019
# 56989092                8.0   8/26/2018
#
# [102599 rows x 19 columns]

# %%
data.shape
# Out:
# (102599, 19)

# %%
data.columns
# Out:
# Index(['Name', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
new_column_names = []
for i in data:
  new_column_names.append(i.upper())
new_column_names
# Out:
# ['NAME',
#  'HOST ID',
#  'HOST_IDENTITY_VERIFIED',
#  'HOST NAME',
#  'NEIGHBOURHOOD GROUP',
#  'NEIGHBOURHOOD',
#  'LAT',
#  'LONG',
#  'COUNTRY',
#  'COUNTRY CODE',
#  'INSTANT_BOOKABLE',
#  'CANCELLATION_POLICY',
#  'ROOM TYPE',
#  'CONSTRUCTION YEAR',
#  'PRICE',
#  'SERVICE FEE',
#  'MINIMUM NIGHTS',
#  'NUMBER OF REVIEWS',
#  'LAST REVIEW']

# %%
new_dataframe_to_modify = data.copy()

# %%
new_dataframe_to_modify.columns
# Out:
# Index(['Name', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
new_dataframe_to_modify.columns = new_column_names

# %%
new_dataframe_to_modify.columns
# Out:
# Index(['NAME', 'HOST ID', 'HOST_IDENTITY_VERIFIED', 'HOST NAME',
#        'NEIGHBOURHOOD GROUP', 'NEIGHBOURHOOD', 'LAT', 'LONG', 'COUNTRY',
#        'COUNTRY CODE', 'INSTANT_BOOKABLE', 'CANCELLATION_POLICY', 'ROOM TYPE',
#        'CONSTRUCTION YEAR', 'PRICE', 'SERVICE FEE', 'MINIMUM NIGHTS',
#        'NUMBER OF REVIEWS', 'LAST REVIEW'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(541)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Name                        250
# host id                       0
# host_identity_verified      289
# host name                   404
# neighbourhood group          29
# neighbourhood                16
# lat                           8
# long                          8
# country                     532
# country code                131
# instant_bookable            105
# cancellation_policy          76
# room type                     0
# Construction year           214
# price                       247
# service fee                 273
# minimum nights              400
# number of reviews           183
# last review               15832
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isna().sum()
# Out:
# Name                      0
# host id                   0
# host_identity_verified    0
# host name                 0
# neighbourhood group       0
# neighbourhood             0
# lat                       0
# long                      0
# country                   0
# country code              0
# instant_bookable          0
# cancellation_policy       0
# room type                 0
# Construction year         0
# price                     0
# service fee               0
# minimum nights            0
# number of reviews         0
# last review               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
df['host_identity_verified']
# Out:
# id
# 1001254     unconfirmed
# 38763192    unconfirmed
# 38762639    unconfirmed
# 38762087       verified
# 38760982       verified
#                ...
# 19839184       verified
# 19838632    unconfirmed
# 19837528    unconfirmed
# 19836423       verified
# 19835318    unconfirmed
# Name: host_identity_verified, Length: 83969, dtype: object

# %%
df['host_identity_verified'] = df['host_identity_verified'].str.upper()

# %%
df
# Out:
#                                                        Name      host id  \
# id
# 1001254                  Clean & quiet apt home by the park  80014485718
# 38763192  Big One Bedroom Directly Across from Central P...  36257056231
# 38762639                 Affordable 2 Bedroom on the UES!!!  83771419475
# 38762087                            Charming 1 br apartment   8856169091
# 38760982                    Artist's Room in Prime Bushwick  12458494587
# ...                                                     ...          ...
# 19839184            Modern Living in Soho/Noho/West Village  62024966266
# 19838632                         Central Park Spacious Room  74378693322
# 19837528  Prime East Village Manhattan w/ Beautiful Back...  58958151239
# 19836423                       Brooklyn home away from home  36982711686
# 19835318           Stunning bedroom in trendy Williamsburg!  77736603165
#
#          host_identity_verified host name neighbourhood group  \
# id
# 1001254             UNCONFIRMED  Madaline            Brooklyn
# 38763192            UNCONFIRMED     Shaye           Manhattan
# 38762639            UNCONFIRMED       Zoe           Manhattan
# 38762087               VERIFIED    Andrew            Brooklyn
# 38760982               VERIFIED       Lux            Brooklyn
# ...                         ...       ...                 ...
# 19839184               VERIFIED      Jeff           Manhattan
# 19838632            UNCONFIRMED   Hongzhi           Manhattan
# 19837528            UNCONFIRMED    Thomas           Manhattan
# 19836423               VERIFIED    Sofiya            Brooklyn
# 19835318            UNCONFIRMED      Nina            Brooklyn
#
#               neighbourhood       lat      long        country country code  \
# id
# 1001254          Kensington  40.64749 -73.97237  United States           US
# 38763192    Upper West Side  40.79982 -73.96058  United States           US
# 38762639    Upper East Side  40.76644 -73.95486  United States           US
# 38762087           Bushwick  40.70587 -73.92358  United States           US
# 38760982           Bushwick  40.70100 -73.91986  United States           US
# ...                     ...       ...       ...            ...          ...
# 19839184  Greenwich Village  40.72674 -73.99673  United States           US
# 19838632    Upper West Side  40.79908 -73.96215  United States           US
# 19837528       East Village  40.72769 -73.98498  United States           US
# 19836423        Sunset Park  40.66153 -73.99297  United States           US
# 19835318       Williamsburg  40.71407 -73.93936  United States           US
#
#          instant_bookable cancellation_policy        room type  \
# id
# 1001254             False              strict     Private room
# 38763192            False              strict  Entire home/apt
# 38762639             True            moderate  Entire home/apt
# 38762087             True              strict  Entire home/apt
# 38760982            False            moderate     Private room
# ...                   ...                 ...              ...
# 19839184             True            moderate  Entire home/apt
# 19838632             True            moderate     Private room
# 19837528             True            moderate     Private room
# 19836423            False              strict     Private room
# 19835318             True              strict     Private room
#
#           Construction year    price service fee  minimum nights  \
# id
# 1001254              2020.0    $966        $193             10.0
# 38763192             2013.0    $286         $57              2.0
# 38762639             2010.0    $858        $172              3.0
# 38762087             2013.0    $766        $153              2.0
# 38760982             2016.0     $92         $18              1.0
# ...                     ...      ...         ...             ...
# 19839184             2021.0    $451         $90              3.0
# 19838632             2017.0    $763        $153              1.0
# 19837528             2011.0  $1,121        $224              1.0
# 19836423             2018.0    $399         $80              1.0
# 19835318             2014.0    $186         $37             30.0
#
#           number of reviews last review
# id
# 1001254                 9.0  10/19/2021
# 38763192                1.0   9/10/2017
# 38762639                3.0   9/28/2017
# 38762087               13.0   4/15/2018
# 38760982               77.0    7/7/2019
# ...                     ...         ...
# 19839184                6.0    7/1/2019
# 19838632               14.0   8/23/2018
# 19837528                3.0   6/22/2019
# 19836423                6.0   6/23/2019
# 19835318                2.0    7/6/2019
#
# [83969 rows x 19 columns]

# %%
df['instant_bookable']
# Out:
# id
# 1001254     False
# 38763192    False
# 38762639     True
# 38762087     True
# 38760982    False
#             ...
# 19839184     True
# 19838632     True
# 19837528     True
# 19836423    False
# 19835318     True
# Name: instant_bookable, Length: 83969, dtype: object

# %%
df['instant_bookable'] = df['instant_bookable'].apply(lambda x : 1 if x == True else 0)

# %%
df.reset_index(inplace=True)

# %%
type(df['instant_bookable'][15])
# Out:
# numpy.int64

# %%
data['price']
# Out:
# id
# 1001254       $966
# 38763192      $286
# 38762639      $858
# 38762087      $766
# 38761535      $198
#              ...
# 56986882      $765
# 56987435      $201
# 56987987      $132
# 56988539      $940
# 56989092    $1,020
# Name: price, Length: 102599, dtype: object

# %%
df['price'] = df['price'].str.replace("$", "")

# %%
df['price']
# Out:
# 0          966
# 1          286
# 2          858
# 3          766
# 4           92
#           ...
# 83964      451
# 83965      763
# 83966    1,121
# 83967      399
# 83968      186
# Name: price, Length: 83969, dtype: object

# %%
df['price'] = df['price'].str.replace(',', '')

# %%
df['price']
# Out:
# 0         966
# 1         286
# 2         858
# 3         766
# 4          92
#          ...
# 83964     451
# 83965     763
# 83966    1121
# 83967     399
# 83968     186
# Name: price, Length: 83969, dtype: object

# %%
df['price'][15]
# Out:
# '761 '

# %%
df['price'] = df['price'].replace([' ', ''])
# Out:
# /var/folders/zs/6h03lndj5114078br2jdh8380000gn/T/ipykernel_9750/1521255269.py:1: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df['price'] = df['price'].replace([' ', ''])

# %%
type(df['price'][15])
# Out:
# str

# %%
df['price'] = df['price'].astype(int)

# %%
type(df['price'][15])
# Out:
# numpy.int64

# %%
df
# Out:
#              id                                               Name  \
# 0       1001254                 Clean & quiet apt home by the park
# 1      38763192  Big One Bedroom Directly Across from Central P...
# 2      38762639                 Affordable 2 Bedroom on the UES!!!
# 3      38762087                            Charming 1 br apartment
# 4      38760982                    Artist's Room in Prime Bushwick
# ...         ...                                                ...
# 83964  19839184            Modern Living in Soho/Noho/West Village
# 83965  19838632                         Central Park Spacious Room
# 83966  19837528  Prime East Village Manhattan w/ Beautiful Back...
# 83967  19836423                       Brooklyn home away from home
# 83968  19835318           Stunning bedroom in trendy Williamsburg!
#
#            host id host_identity_verified host name neighbourhood group  \
# 0      80014485718            UNCONFIRMED  Madaline            Brooklyn
# 1      36257056231            UNCONFIRMED     Shaye           Manhattan
# 2      83771419475            UNCONFIRMED       Zoe           Manhattan
# 3       8856169091               VERIFIED    Andrew            Brooklyn
# 4      12458494587               VERIFIED       Lux            Brooklyn
# ...            ...                    ...       ...                 ...
# 83964  62024966266               VERIFIED      Jeff           Manhattan
# 83965  74378693322            UNCONFIRMED   Hongzhi           Manhattan
# 83966  58958151239            UNCONFIRMED    Thomas           Manhattan
# 83967  36982711686               VERIFIED    Sofiya            Brooklyn
# 83968  77736603165            UNCONFIRMED      Nina            Brooklyn
#
#            neighbourhood       lat      long        country country code  \
# 0             Kensington  40.64749 -73.97237  United States           US
# 1        Upper West Side  40.79982 -73.96058  United States           US
# 2        Upper East Side  40.76644 -73.95486  United States           US
# 3               Bushwick  40.70587 -73.92358  United States           US
# 4               Bushwick  40.70100 -73.91986  United States           US
# ...                  ...       ...       ...            ...          ...
# 83964  Greenwich Village  40.72674 -73.99673  United States           US
# 83965    Upper West Side  40.79908 -73.96215  United States           US
# 83966       East Village  40.72769 -73.98498  United States           US
# 83967        Sunset Park  40.66153 -73.99297  United States           US
# 83968       Williamsburg  40.71407 -73.93936  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                     0              strict     Private room
# 1                     0              strict  Entire home/apt
# 2                     1            moderate  Entire home/apt
# 3                     1              strict  Entire home/apt
# 4                     0            moderate     Private room
# ...                 ...                 ...              ...
# 83964                 1            moderate  Entire home/apt
# 83965                 1            moderate     Private room
# 83966                 1            moderate     Private room
# 83967                 0              strict     Private room
# 83968                 1              strict     Private room
#
#        Construction year  price service fee  minimum nights  \
# 0                 2020.0    966       $193             10.0
# 1                 2013.0    286        $57              2.0
# 2                 2010.0    858       $172              3.0
# 3                 2013.0    766       $153              2.0
# 4                 2016.0     92        $18              1.0
# ...                  ...    ...         ...             ...
# 83964             2021.0    451        $90              3.0
# 83965             2017.0    763       $153              1.0
# 83966             2011.0   1121       $224              1.0
# 83967             2018.0    399        $80              1.0
# 83968             2014.0    186        $37             30.0
#
#        number of reviews last review
# 0                    9.0  10/19/2021
# 1                    1.0   9/10/2017
# 2                    3.0   9/28/2017
# 3                   13.0   4/15/2018
# 4                   77.0    7/7/2019
# ...                  ...         ...
# 83964                6.0    7/1/2019
# 83965               14.0   8/23/2018
# 83966                3.0   6/22/2019
# 83967                6.0   6/23/2019
# 83968                2.0    7/6/2019
#
# [83969 rows x 20 columns]

# %%
df.to_csv('cleaned_data.csv')

# %%
df_cleaned = pd.read_csv('cleaned_data.csv')
df_cleaned
# Out:
#        Unnamed: 0        id  \
# 0               0   1001254
# 1               1  38763192
# 2               2  38762639
# 3               3  38762087
# 4               4  38760982
# ...           ...       ...
# 83964       83964  19839184
# 83965       83965  19838632
# 83966       83966  19837528
# 83967       83967  19836423
# 83968       83968  19835318
#
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1      Big One Bedroom Directly Across from Central P...  36257056231
# 2                     Affordable 2 Bedroom on the UES!!!  83771419475
# 3                                Charming 1 br apartment   8856169091
# 4                        Artist's Room in Prime Bushwick  12458494587
# ...                                                  ...          ...
# 83964            Modern Living in Soho/Noho/West Village  62024966266
# 83965                         Central Park Spacious Room  74378693322
# 83966  Prime East Village Manhattan w/ Beautiful Back...  58958151239
# 83967                       Brooklyn home away from home  36982711686
# 83968           Stunning bedroom in trendy Williamsburg!  77736603165
#
#       host_identity_verified host name neighbourhood group      neighbourhood  \
# 0                UNCONFIRMED  Madaline            Brooklyn         Kensington
# 1                UNCONFIRMED     Shaye           Manhattan    Upper West Side
# 2                UNCONFIRMED       Zoe           Manhattan    Upper East Side
# 3                   VERIFIED    Andrew            Brooklyn           Bushwick
# 4                   VERIFIED       Lux            Brooklyn           Bushwick
# ...                      ...       ...                 ...                ...
# 83964               VERIFIED      Jeff           Manhattan  Greenwich Village
# 83965            UNCONFIRMED   Hongzhi           Manhattan    Upper West Side
# 83966            UNCONFIRMED    Thomas           Manhattan       East Village
# 83967               VERIFIED    Sofiya            Brooklyn        Sunset Park
# 83968            UNCONFIRMED      Nina            Brooklyn       Williamsburg
#
#             lat      long        country country code  instant_bookable  \
# 0      40.64749 -73.97237  United States           US                 0
# 1      40.79982 -73.96058  United States           US                 0
# 2      40.76644 -73.95486  United States           US                 1
# 3      40.70587 -73.92358  United States           US                 1
# 4      40.70100 -73.91986  United States           US                 0
# ...         ...       ...            ...          ...               ...
# 83964  40.72674 -73.99673  United States           US                 1
# 83965  40.79908 -73.96215  United States           US                 1
# 83966  40.72769 -73.98498  United States           US                 1
# 83967  40.66153 -73.99297  United States           US                 0
# 83968  40.71407 -73.93936  United States           US                 1
#
#       cancellation_policy        room type  Construction year  price  \
# 0                  strict     Private room             2020.0    966
# 1                  strict  Entire home/apt             2013.0    286
# 2                moderate  Entire home/apt             2010.0    858
# 3                  strict  Entire home/apt             2013.0    766
# 4                moderate     Private room             2016.0     92
# ...                   ...              ...                ...    ...
# 83964            moderate  Entire home/apt             2021.0    451
# 83965            moderate     Private room             2017.0    763
# 83966            moderate     Private room             2011.0   1121
# 83967              strict     Private room             2018.0    399
# 83968              strict     Private room             2014.0    186
#
#       service fee  minimum nights  number of reviews last review
# 0           $193             10.0                9.0  10/19/2021
# 1            $57              2.0                1.0   9/10/2017
# 2           $172              3.0                3.0   9/28/2017
# 3           $153              2.0               13.0   4/15/2018
# 4            $18              1.0               77.0    7/7/2019
# ...           ...             ...                ...         ...
# 83964        $90              3.0                6.0    7/1/2019
# 83965       $153              1.0               14.0   8/23/2018
# 83966       $224              1.0                3.0   6/22/2019
# 83967        $80              1.0                6.0   6/23/2019
# 83968        $37             30.0                2.0    7/6/2019
#
# [83969 rows x 21 columns]

# %%
df.to_csv('cleaned_df.csv', index=False)

# %%
df_clean = pd.read_csv('cleaned_df.csv')
df_clean
# Out:
#              id                                               Name  \
# 0       1001254                 Clean & quiet apt home by the park
# 1      38763192  Big One Bedroom Directly Across from Central P...
# 2      38762639                 Affordable 2 Bedroom on the UES!!!
# 3      38762087                            Charming 1 br apartment
# 4      38760982                    Artist's Room in Prime Bushwick
# ...         ...                                                ...
# 83964  19839184            Modern Living in Soho/Noho/West Village
# 83965  19838632                         Central Park Spacious Room
# 83966  19837528  Prime East Village Manhattan w/ Beautiful Back...
# 83967  19836423                       Brooklyn home away from home
# 83968  19835318           Stunning bedroom in trendy Williamsburg!
#
#            host id host_identity_verified host name neighbourhood group  \
# 0      80014485718            UNCONFIRMED  Madaline            Brooklyn
# 1      36257056231            UNCONFIRMED     Shaye           Manhattan
# 2      83771419475            UNCONFIRMED       Zoe           Manhattan
# 3       8856169091               VERIFIED    Andrew            Brooklyn
# 4      12458494587               VERIFIED       Lux            Brooklyn
# ...            ...                    ...       ...                 ...
# 83964  62024966266               VERIFIED      Jeff           Manhattan
# 83965  74378693322            UNCONFIRMED   Hongzhi           Manhattan
# 83966  58958151239            UNCONFIRMED    Thomas           Manhattan
# 83967  36982711686               VERIFIED    Sofiya            Brooklyn
# 83968  77736603165            UNCONFIRMED      Nina            Brooklyn
#
#            neighbourhood       lat      long        country country code  \
# 0             Kensington  40.64749 -73.97237  United States           US
# 1        Upper West Side  40.79982 -73.96058  United States           US
# 2        Upper East Side  40.76644 -73.95486  United States           US
# 3               Bushwick  40.70587 -73.92358  United States           US
# 4               Bushwick  40.70100 -73.91986  United States           US
# ...                  ...       ...       ...            ...          ...
# 83964  Greenwich Village  40.72674 -73.99673  United States           US
# 83965    Upper West Side  40.79908 -73.96215  United States           US
# 83966       East Village  40.72769 -73.98498  United States           US
# 83967        Sunset Park  40.66153 -73.99297  United States           US
# 83968       Williamsburg  40.71407 -73.93936  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                     0              strict     Private room
# 1                     0              strict  Entire home/apt
# 2                     1            moderate  Entire home/apt
# 3                     1              strict  Entire home/apt
# 4                     0            moderate     Private room
# ...                 ...                 ...              ...
# 83964                 1            moderate  Entire home/apt
# 83965                 1            moderate     Private room
# 83966                 1            moderate     Private room
# 83967                 0              strict     Private room
# 83968                 1              strict     Private room
#
#        Construction year  price service fee  minimum nights  \
# 0                 2020.0    966       $193             10.0
# 1                 2013.0    286        $57              2.0
# 2                 2010.0    858       $172              3.0
# 3                 2013.0    766       $153              2.0
# 4                 2016.0     92        $18              1.0
# ...                  ...    ...         ...             ...
# 83964             2021.0    451        $90              3.0
# 83965             2017.0    763       $153              1.0
# 83966             2011.0   1121       $224              1.0
# 83967             2018.0    399        $80              1.0
# 83968             2014.0    186        $37             30.0
#
#        number of reviews last review
# 0                    9.0  10/19/2021
# 1                    1.0   9/10/2017
# 2                    3.0   9/28/2017
# 3                   13.0   4/15/2018
# 4                   77.0    7/7/2019
# ...                  ...         ...
# 83964                6.0    7/1/2019
# 83965               14.0   8/23/2018
# 83966                3.0   6/22/2019
# 83967                6.0   6/23/2019
# 83968                2.0    7/6/2019
#
# [83969 rows x 20 columns]

# %%
df.to_excel('excel_cleaned_data.xlsx', index=False)

# %%
df_excel = pd.read_excel('excel_cleaned_data.xlsx')
df_excel
# Out:
#              id                                               Name  \
# 0       1001254                 Clean & quiet apt home by the park
# 1      38763192  Big One Bedroom Directly Across from Central P...
# 2      38762639                 Affordable 2 Bedroom on the UES!!!
# 3      38762087                            Charming 1 br apartment
# 4      38760982                    Artist's Room in Prime Bushwick
# ...         ...                                                ...
# 83964  19839184            Modern Living in Soho/Noho/West Village
# 83965  19838632                         Central Park Spacious Room
# 83966  19837528  Prime East Village Manhattan w/ Beautiful Back...
# 83967  19836423                       Brooklyn home away from home
# 83968  19835318           Stunning bedroom in trendy Williamsburg!
#
#            host id host_identity_verified host name neighbourhood group  \
# 0      80014485718            UNCONFIRMED  Madaline            Brooklyn
# 1      36257056231            UNCONFIRMED     Shaye           Manhattan
# 2      83771419475            UNCONFIRMED       Zoe           Manhattan
# 3       8856169091               VERIFIED    Andrew            Brooklyn
# 4      12458494587               VERIFIED       Lux            Brooklyn
# ...            ...                    ...       ...                 ...
# 83964  62024966266               VERIFIED      Jeff           Manhattan
# 83965  74378693322            UNCONFIRMED   Hongzhi           Manhattan
# 83966  58958151239            UNCONFIRMED    Thomas           Manhattan
# 83967  36982711686               VERIFIED    Sofiya            Brooklyn
# 83968  77736603165            UNCONFIRMED      Nina            Brooklyn
#
#            neighbourhood       lat      long        country country code  \
# 0             Kensington  40.64749 -73.97237  United States           US
# 1        Upper West Side  40.79982 -73.96058  United States           US
# 2        Upper East Side  40.76644 -73.95486  United States           US
# 3               Bushwick  40.70587 -73.92358  United States           US
# 4               Bushwick  40.70100 -73.91986  United States           US
# ...                  ...       ...       ...            ...          ...
# 83964  Greenwich Village  40.72674 -73.99673  United States           US
# 83965    Upper West Side  40.79908 -73.96215  United States           US
# 83966       East Village  40.72769 -73.98498  United States           US
# 83967        Sunset Park  40.66153 -73.99297  United States           US
# 83968       Williamsburg  40.71407 -73.93936  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                     0              strict     Private room
# 1                     0              strict  Entire home/apt
# 2                     1            moderate  Entire home/apt
# 3                     1              strict  Entire home/apt
# 4                     0            moderate     Private room
# ...                 ...                 ...              ...
# 83964                 1            moderate  Entire home/apt
# 83965                 1            moderate     Private room
# 83966                 1            moderate     Private room
# 83967                 0              strict     Private room
# 83968                 1              strict     Private room
#
#        Construction year  price service fee  minimum nights  \
# 0                   2020    966       $193               10
# 1                   2013    286        $57                2
# 2                   2010    858       $172                3
# 3                   2013    766       $153                2
# 4                   2016     92        $18                1
# ...                  ...    ...         ...             ...
# 83964               2021    451        $90                3
# 83965               2017    763       $153                1
# 83966               2011   1121       $224                1
# 83967               2018    399        $80                1
# 83968               2014    186        $37               30
#
#        number of reviews last review
# 0                      9  10/19/2021
# 1                      1   9/10/2017
# 2                      3   9/28/2017
# 3                     13   4/15/2018
# 4                     77    7/7/2019
# ...                  ...         ...
# 83964                  6    7/1/2019
# 83965                 14   8/23/2018
# 83966                  3   6/22/2019
# 83967                  6   6/23/2019
# 83968                  2    7/6/2019
#
# [83969 rows x 20 columns]
