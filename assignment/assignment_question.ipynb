# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
name = input('What is your name?')
print(name)
# Out:
# Ashish

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num = int(input('Enter a number: '))
if num > 0:
  print('positive')
elif num < 0:
  print("negative")
else:
  print("Zero")
# Out:
# negative

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
a = 17
b = 21
c = 15
max = a
if a < b:
  if b < c :
    max = c
  else:
    max = b
elif a < c:
  if c < b:
    max = b
  else:
    max = c
print(max)
# Out:
# 21

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
n = int(input('Enter number you want factorial of: '))
def fact(n):
  if n == 0:
    return 1
  else:
    return n * fact(n-1)

print(fact(n))
# Out:
# 24

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
a = 13
b = 14.5
c = 'Ashish'
d = True

print(f"Data type of {a} is: {type(a)}")
print(f"Data type of {b} is: {type(b)}")
print(f"Data type of {c} is: {type(c)}")
print(f"Data type of {d} is: {type(d)}")
# Out:
# Data type of 13 is: <class 'int'>
# Data type of 14.5 is: <class 'float'>
# Data type of Ashish is: <class 'str'>
# Data type of True is: <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a = 10
b = 15
def swap(a, b) :
  a, b = b, a
  return a, b
print(swap(a, b))
# Out:
# (15, 10)

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
temp = float(input("Enter temperature in celsisu: "))
F = temp * 9/5 + 32
print(F)
# Out:
# 219.2

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
firstName = 'Ashish'
lastName = 'Khanagwal'
fullName = firstName + " " + lastName
print('Full name is: ', fullName)
# Out:
# Full name is:  Ashish Khanagwal

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
a = "Ashish"
if isinstance(a, str):
  print('String')
else:
  print('not string')
# Out:
# String

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a = 10
b = 5
print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# 15
# 5
# 50
# 2.0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
a = 10
b = 12

print(f"{a} == {b} : {a == b}")
print(f"{a} != {b} : {a != b}")
print(f"{a} > {b} : {a > b}")
print(f"{a} < {b} : {a < b}")
# Out:
# 10 == 12 : False
# 10 != 12 : True
# 10 > 12 : False
# 10 < 12 : True

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
age = int(input("Enter your age? "))
if age >= 18 and age <= 30:
  print("You can enter to Master's program.")
else:
  print("sorry, you can't.")
# Out:
# sorry, you can't.

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
num = int(input("Enter a number you want to calculate square of: "))
print(num*num)
# Out:
# 169

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = int(input('Enter a number: '))
if num % 2 == 1:
  print('odd')
else:
  print('even')
# Out:
# even

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
n = int(input('Enter the number: '))
sum = 0
for i in range(1, n+1):
  sum += i
print(sum)
# Out:
# 15

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
year = int(input("Enter a year: "))

if year % 400 == 0 or (year % 4 == 0 and year % 100 != 0):
  print('leap year')
else:
  print('not a leap year.')
# Out:
# leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
s = "Ashish"
r = s[::-1]
print(r)
# Out:
# hsihsA

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
s = input('Enter somehthign you want to check if palindrome or not: ')
r = s[::-1]
if r == s:
  print('yes, palindrome')
else:
  print("not palindrome")
# Out:
# yes, palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
num = [int(x) for x in input('Enter numbers seperatd by space').split()]
num.sort()
print(num)
# Out:
# [1, 2, 12, 32, 43, 89]
