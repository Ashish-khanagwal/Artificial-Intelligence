# %% [markdown]
# ### Assignment 1: Reading a File
#
# Write a function that reads the contents of a file named `sample.txt` and prints each line.

# %%
with open('sameple.txt', 'w') as file:
  file.write("Hey\nI am Ashish\nI hope you're doing good.\nI am absolutedly great")

# %%
with open('sameple.txt', 'r') as file:
  content = file.read()
  print(content)
# Out:
# Hey
# I am Ashish
# I hope you're doing good.
# I am absolutedly great

# %% [markdown]
# ### Assignment 2: Writing to a File
#
# Write a function that writes a list of strings to a file named `output.txt`, with each string on a new line.

# %%
with open('string.txt', 'w') as file:
  line = "Hey\nSo, I am a tech nerd\nI love to explore the mysterious world of tech where the mostly coders end their ability to think.\nIn case i haven't told you yet, Then I am Ashish."
  file.write(line)

# %% [markdown]
# ### Assignment 3: Copying a File
#
# Write a function that copies the contents of a file named `source.txt` to a new file named `destination.txt`.

# %%
with open('source.txt', 'r') as source_file:
  content = source_file.read()

with open('destination.txt', 'w') as destination_file:
  destination_file.write(content)

# %% [markdown]
# ### Assignment 4: Appending to a File
#
# Write a function that appends a given string to the end of a file named `log.txt`.

# %%
def append_str(file, s):
  with open(file, 'a') as s_file:
    s_file.write(s)

  with open(file, 'r') as s_file:
    content = s_file.read()
    return content

print(append_str('log.txt', 'heya'))
# Out:
# Hey
# So, I am a tech nerd
# I love to explore the mysterious world of tech where the mostly coders end their ability to think.
# In case i haven't told you yet, Then I am Ashish.
# heya

# %% [markdown]
# ### Assignment 5: Counting Words in a File
#
# Write a function that reads the contents of a file named `document.txt` and returns the number of words in the file.

# %%
def count_word(file):
  with open(file, 'r') as s_file:
    lines = s_file.readlines()
    word = sum(len(line.split()) for line in lines)
    return word

print(count_word('destination.txt'))
# Out:
# 26

# %% [markdown]
# ### Assignment 6: Finding and Replacing Text
#
# Write a function that finds and replaces all occurrences of a given word in a file named `data.txt` with another word.

# %%
def replace_word(file, c):
  with open(file, 'r') as f:
    content = f.read()

  updated_content = content.replace('bright', c)

  with open(file, 'w') as f:
    f.write(updated_content)

  print(f'All occurrences of "bright" replaced with "{c}" in {file}.')

replace_word('data.txt', 'luminous')

with open("data.txt", "r") as f:
    print("\nFile content after replacement:")
    print(f.read())
# Out:
# All occurrences of "bright" replaced with "luminous" in data.txt.
#
# File content after replacement:
# The morning felt unusually luminous, filling the room with a luminous
# glow that encouraged me to begin working earlier than usual.
# Even the smallest tasks seemed easier under such luminous conditions,
# reminding me how strongly the environment influences focus and motivation throughout the day.

# %% [markdown]
# ### Assignment 7: Reading a File in Reverse
#
# Write a function that reads the contents of a file named `reverse.txt` and prints each line in reverse order.

# %%
def reverse_txt(file):
  with open(file, 'r') as f:
    lines = f.readlines()
    l = [line for line in lines]
    l = l[::-1]
    return l
print(reverse_txt('destination.txt'))
# Out:
# ['then you will find me in destination.txt as well.\n', 'and i am sure if your copying method will work\n', 'This is a source file,\n', 'Hey there,\n']

# %% [markdown]
# ### Assignment 8: Counting Lines, Words, and Characters
#
# Write a function that reads the contents of a file named `stats.txt` and returns the number of lines, words, and characters in the file.

# %%
def count_freq(file):
  with open(file, 'r') as f:
    lines = f.readlines()

    lines_freq = len(lines)
    word_count = sum(len(line.split()) for line in lines)
    char_count = sum(len(line) for line in lines)

  return f"The number of lines in file {file}: {lines_freq}, number of words: {word_count}, and number of characters: {char_count}"

print(count_freq('destination.txt'))
# Out:
# The number of lines in file destination.txt: 4, number of words: 26, and number of characters: 131

# %% [markdown]
# ### Assignment 9: Merging Multiple Files
#
# Write a function that merges the contents of multiple files into a single file named `merged.txt`.

# %%
def merging_files(file1, file2):
  with open(file1, 'r') as f1:
    content1 = f1.read()

  with open(file2, 'r') as f2:
    content2 = f2.read()

  with open('merged.txt', 'w') as f3:
    f3.write(content1 + "\n" + content2)
  
  with open('merged.txt', 'r') as f3:
    content = f3.read()

  return content

print(merging_files('data.txt', 'destination.txt'))
# Out:
# The morning felt unusually luminous, filling the room with a luminous
# glow that encouraged me to begin working earlier than usual.
# Even the smallest tasks seemed easier under such luminous conditions,
# reminding me how strongly the environment influences focus and motivation throughout the day.
#
# Hey there,
# This is a source file,
# and i am sure if your copying method will work
# then you will find me in destination.txt as well.

# %% [markdown]
# ### Assignment 10: Splitting a Large File
#
# Write a function that splits a large file named `large.txt` into smaller files of 100 lines each.

# %%
def split_file(filename, lines_per_file):
    with open(filename, 'r') as file:
        lines = file.readlines()
    for i in range(0, len(lines), lines_per_file):
        with open(f'{filename}_part{i//lines_per_file + 1}.txt', 'w') as part_file:
            part_file.writelines(lines[i:i + lines_per_file])

# Test
split_file('large.txt', 5)

# %% [markdown]
# ### Assignment 11: Creating a Log File
#
# Write a function that creates a log file named `activity.log` and writes log messages with timestamps.

# %%
import datetime

def log_message(message, filename='activity.log'):
  timestamp = datetime.datetime.now().isoformat()
  with open(filename, 'a') as file:
    file.write(f'[{timestamp}] {message}\n')

log_message('This is a log message.')

# %% [markdown]
# ### Assignment 12: Binary File Operations
#
# Write a function that reads a binary file named `image.bin` and writes its contents to another binary file named `copy_image.bin`.

# %%
def copy_binary_file(source, destination):
    with open(source, 'rb') as src:
        with open(destination, 'wb') as dest:
            dest.write(src.read())

copy_binary_file('image.bin', 'copy_image.bin')

# %% [markdown]
# ### Assignment 13: CSV File Operations
#
# Write a function that reads a CSV file named `data.csv` and prints its contents as a list of dictionaries.

# %%
import csv

def read_csv(filename):
  with open(filename, 'r') as file:
    reader = csv.DictReader(file)
    return list(reader)
  
print(read_csv('data.csv'))
# Out:
# [{'Name': 'Virat Kohli', 'Country': 'India', 'Role': 'Batsman', 'Matches': '275', 'Runs': '13000'}, {'Name': 'Rohit Sharma', 'Country': 'India', 'Role': 'Batsman', 'Matches': '254', 'Runs': '10709'}, {'Name': 'Kane Williamson', 'Country': 'New Zealand', 'Role': 'Batsman', 'Matches': '165', 'Runs': '6554'}, {'Name': 'Joe Root', 'Country': 'England', 'Role': 'Batsman', 'Matches': '164', 'Runs': '6242'}, {'Name': 'Babar Azam', 'Country': 'Pakistan', 'Role': 'Batsman', 'Matches': '117', 'Runs': '5802'}]

# %% [markdown]
# ### Assignment 14: JSON File Operations
#
# Write a function that reads a JSON file named `data.json` and prints its contents as a Python dictionary.

# %%
import json

def read_json(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
        return data

print(read_json('data.json'))
# Out:
# [{'name': 'Virat Kohli', 'country': 'India', 'role': 'Batsman', 'matches': 275, 'runs': 13000}, {'name': 'Rohit Sharma', 'country': 'India', 'role': 'Batsman', 'matches': 254, 'runs': 10709}, {'name': 'Kane Williamson', 'country': 'New Zealand', 'role': 'Batsman', 'matches': 165, 'runs': 6554}, {'name': 'Joe Root', 'country': 'England', 'role': 'Batsman', 'matches': 164, 'runs': 6242}, {'name': 'Babar Azam', 'country': 'Pakistan', 'role': 'Batsman', 'matches': 117, 'runs': 5802}]

# %% [markdown]
# ### Assignment 15: File Permission Handling
#
# Write a function that attempts to read a file named `protected.txt` and handles any permission errors gracefully by printing an error message.

# %%
def read_protected_file(filename):
    try:
        with open(filename, 'r') as file:
            print(file.read())
    except PermissionError as e:
        print(f"Permission error: {e}")

read_protected_file('protected.txt')
# Out:
# Permission error: [Errno 13] Permission denied: 'protected.txt'
